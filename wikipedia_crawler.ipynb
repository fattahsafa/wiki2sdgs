# %% [markdown]
# # Initialization

# %% [markdown]
# ## Import libraries

# %%
import requests
import os
import json
import re
import torch
import pandas as pd
import numpy as np
import http.client
import urllib.parse

# %% [markdown]
# ## Set Variables

# %%
use_colab = False
positionstack_api_key = 'a185ca6660614f712266ea5e80e00e06'
positionstack_api = 'http://api.positionstack.com'
countriesnow_api = 'https://countriesnow.space'
wikipedia_api = 'https://en.wikipedia.org/w/api.php?'

if (use_colab):
    from google.colab import drive
    drive.mount('/content/drive')
    dataset_directory = '/content/drive/MyDrive/Colab/datasets/wikipedia_to_sdgs'
    workspace = '/content/drive/MyDrive/Colab/wikipedia_to_sdgs'
else:
    workspace = '.'

sdgs_corpus_titles_path = os.path.join(workspace, 'sdgs_titles.json')
countries_file_path = os.path.join(workspace, 'countries.txt')
country_articles_file_path = os.path.join(workspace, 'country_articles.json')
corpus_directory = os.path.join(workspace, 'articles')

# %% [markdown]
# # Construct the corpus

# %% [markdown]
# ## Get country cities using https://countriesnow.space

# %%
def retrieve_citites(country):
    cities = []

    headers = {"Content-Type": "application/json; charset=utf-8"}
    body = {
        "country": country,
    }
    response = requests.post(countriesnow_api+'/api/v0.1/countries/cities', headers=headers, json=body)
    data = response.json()['data']
    for index in range(len(data)):
        city = data[index]
        cities.append(city)

    return cities

# %% [markdown]
# ## Get country geo-location
# Use https://positionstack.com/ to retrieve the geolocation of a country

# %%
def retrieve_country_geolocation(country):
    params = urllib.parse.urlencode({
    'access_key': positionstack_api_key,
    'query':country,
    })
    response = requests.get(positionstack_api+'/v1/forward?', params=params)
    data = response.json()['data']
    for index in range(len(data)):
        if data[index]['type']=='country':
            latitude = data[index]['latitude']
            longitude = data[index]['longitude']
            break
    return latitude,longitude

# %%
def retrieve_city_geolocation(country, city):

    params = urllib.parse.urlencode({
    'access_key': positionstack_api_key,
    'query':city+', '+country,
    })
    response = requests.get(positionstack_api+'/v1/forward?', params=params)
    data = response.json()['data']
    if len(data)>0:
        latitude = data[0]['latitude']
        longitude = data[0]['longitude']
    else:
        latitude=None
        longitude=None
        
    return latitude,longitude

# %% [markdown]
# ## Get articles near geolocation

# %%
def retrieve_nearby_articles(latitude, longitude):
    page_titles = []

    request= wikipedia_api+'action=query&list=geosearch&gscoord='+str(latitude)+'|'+str(longitude)+'&gsradius=10000&gslimit=max&format=json'
    response = requests.get(request).json()
    pages = list(response['query']['geosearch'])
    for page_index in range(len(pages)):
        page = pages[page_index]
        title = page['title']
        page_titles.append(title)

    return page_titles

# %% [markdown]
# ## Read the countries

# %%
# opening the file in read mode
countries_file = open(countries_file_path, "r")
# reading the file
countries = countries_file.readlines()

for country_index in range(len(countries)):
    countries[country_index]=countries[country_index].replace('\n', "")
print('Number of found countries: ', len(countries), countries)
# Out:
# Number of found countries:  7 ['Algeria', 'Egypt', 'Morocco', 'Tunisia', 'Libya', 'Sudan', 'Mauritania']

# %% [markdown]
# ## Contruct the countries dictionariy

# %%
country_articles_dict = dict()
for country in countries:
    country_articles = set()
    cities = retrieve_citites(country)
    for city in cities:
        try:
            print('Retrieve geolocation for ',country,', ', city)
            latitude,longitude = retrieve_city_geolocation(country, city)
            print('Retrieve articles for ',country,', ', city)
            city_articles = retrieve_nearby_articles(latitude, longitude)
            country_articles.update(city_articles)
        except:
          print("Erro while retrieving location of data for ", country,", ", city)
    country_articles_dict[country]=list(country_articles)
# Out:
# Retrieve geolocation for  Algeria ,  Algiers
# Retrieve articles for  Algeria ,  Algiers
# Retrieve geolocation for  Algeria ,  Annaba
# Retrieve articles for  Algeria ,  Annaba
# Retrieve geolocation for  Algeria ,  Azazga
# Retrieve articles for  Algeria ,  Azazga
# Retrieve geolocation for  Algeria ,  Batna City
# Retrieve articles for  Algeria ,  Batna City
# Retrieve geolocation for  Algeria ,  Blida
# Retrieve articles for  Algeria ,  Blida
# Retrieve geolocation for  Algeria ,  Bordj
# Retrieve articles for  Algeria ,  Bordj
# Retrieve geolocation for  Algeria ,  Bordj Bou Arreridj
# Retrieve articles for  Algeria ,  Bordj Bou Arreridj
# Retrieve geolocation for  Algeria ,  Bougara
# Retrieve articles for  Algeria ,  Bougara
# Retrieve geolocation for  Algeria ,  Cheraga
# Retrieve articles for  Algeria ,  Cheraga
# Retrieve geolocation for  Algeria ,  Chlef
# Retrieve articles for  Algeria ,  Chlef
# Retrieve geolocation for  Algeria ,  Constantine
# Retrieve articles for  Algeria ,  Constantine
# Retrieve geolocation for  Algeria ,  Djelfa
# Retrieve articles for  Algeria ,  Djelfa
# Retrieve geolocation for  Algeria ,  Draria
# Retrieve articles for  Algeria ,  Draria
# Retrieve geolocation for  Algeria ,  El Tarf
# Retrieve articles for  Algeria ,  El Tarf
# Retrieve geolocation for  Algeria ,  Hussein Dey
# Retrieve articles for  Algeria ,  Hussein Dey
# Retrieve geolocation for  Algeria ,  Illizi
# Retrieve articles for  Algeria ,  Illizi
# Retrieve geolocation for  Algeria ,  Jijel
# Retrieve articles for  Algeria ,  Jijel
# Retrieve geolocation for  Algeria ,  Kouba
# Retrieve articles for  Algeria ,  Kouba
# Retrieve geolocation for  Algeria ,  Laghouat
# Retrieve articles for  Algeria ,  Laghouat
# Retrieve geolocation for  Algeria ,  Oran
# Retrieve articles for  Algeria ,  Oran
# Retrieve geolocation for  Algeria ,  Ouargla
# Retrieve articles for  Algeria ,  Ouargla
# Retrieve geolocation for  Algeria ,  Oued Smar
# Retrieve articles for  Algeria ,  Oued Smar
# Retrieve geolocation for  Algeria ,  Relizane
# Retrieve articles for  Algeria ,  Relizane
# Retrieve geolocation for  Algeria ,  Rouiba
# Retrieve articles for  Algeria ,  Rouiba
# Retrieve geolocation for  Algeria ,  Saida
# Retrieve articles for  Algeria ,  Saida
# Retrieve geolocation for  Algeria ,  Souk Ahras
# Retrieve articles for  Algeria ,  Souk Ahras
# Retrieve geolocation for  Algeria ,  Tamanghasset
# Retrieve articles for  Algeria ,  Tamanghasset
# Retrieve geolocation for  Algeria ,  Tiaret
# Retrieve articles for  Algeria ,  Tiaret
# Retrieve geolocation for  Algeria ,  Tissemsilt
# Retrieve articles for  Algeria ,  Tissemsilt
# Retrieve geolocation for  Algeria ,  Tizi
# Retrieve articles for  Algeria ,  Tizi
# Retrieve geolocation for  Algeria ,  Tizi Ouzou
# Retrieve articles for  Algeria ,  Tizi Ouzou
# Retrieve geolocation for  Algeria ,  Tlemcen
# Retrieve articles for  Algeria ,  Tlemcen
# Retrieve geolocation for  Algeria ,  Adrar
# Retrieve articles for  Algeria ,  Adrar
# Retrieve geolocation for  Algeria ,  Aoulef
# Retrieve articles for  Algeria ,  Aoulef
# Retrieve geolocation for  Algeria ,  Reggane
# Retrieve articles for  Algeria ,  Reggane
# Retrieve geolocation for  Algeria ,  Timimoun
# Retrieve articles for  Algeria ,  Timimoun
# Retrieve geolocation for  Algeria ,  Aïn Defla
# Retrieve articles for  Algeria ,  Aïn Defla
# Retrieve geolocation for  Algeria ,  El Abadia
# Retrieve articles for  Algeria ,  El Abadia
# Retrieve geolocation for  Algeria ,  El Attaf
# Retrieve articles for  Algeria ,  El Attaf
# Retrieve geolocation for  Algeria ,  Khemis Miliana
# Retrieve articles for  Algeria ,  Khemis Miliana
# Retrieve geolocation for  Algeria ,  Theniet el Had
# Retrieve articles for  Algeria ,  Theniet el Had
# Retrieve geolocation for  Algeria ,  Aïn Temouchent
# Retrieve articles for  Algeria ,  Aïn Temouchent
# Retrieve geolocation for  Algeria ,  Beni Saf
# Retrieve articles for  Algeria ,  Beni Saf
# Retrieve geolocation for  Algeria ,  El Amria
# Retrieve articles for  Algeria ,  El Amria
# Retrieve geolocation for  Algeria ,  El Malah
# Retrieve articles for  Algeria ,  El Malah
# Retrieve geolocation for  Algeria ,  Hammam Bou Hadjar
# Retrieve articles for  Algeria ,  Hammam Bou Hadjar
# Retrieve geolocation for  Algeria ,  Aïn Taya
# Retrieve articles for  Algeria ,  Aïn Taya
# Retrieve geolocation for  Algeria ,  Bab Ezzouar
# Retrieve articles for  Algeria ,  Bab Ezzouar
# Retrieve geolocation for  Algeria ,  Birkhadem
# Retrieve articles for  Algeria ,  Birkhadem
# Retrieve geolocation for  Algeria ,  Bordj el Kiffan
# Retrieve articles for  Algeria ,  Bordj el Kiffan
# Retrieve geolocation for  Algeria ,  Dar el Beïda
# Retrieve articles for  Algeria ,  Dar el Beïda
# Retrieve geolocation for  Algeria ,  Berrahal
# Retrieve articles for  Algeria ,  Berrahal
# Retrieve geolocation for  Algeria ,  Drean
# Retrieve articles for  Algeria ,  Drean
# Retrieve geolocation for  Algeria ,  El Hadjar
# Retrieve articles for  Algeria ,  El Hadjar
# Retrieve geolocation for  Algeria ,  Aïn Touta
# Retrieve articles for  Algeria ,  Aïn Touta
# Retrieve geolocation for  Algeria ,  Arris
# Retrieve articles for  Algeria ,  Arris
# Retrieve geolocation for  Algeria ,  Barika
# Retrieve articles for  Algeria ,  Barika
# Retrieve geolocation for  Algeria ,  Batna
# Retrieve articles for  Algeria ,  Batna
# Retrieve geolocation for  Algeria ,  Boumagueur
# Retrieve articles for  Algeria ,  Boumagueur
# Retrieve geolocation for  Algeria ,  Merouana
# Retrieve articles for  Algeria ,  Merouana
# Retrieve geolocation for  Algeria ,  Râs el Aïoun
# Retrieve articles for  Algeria ,  Râs el Aïoun
# Retrieve geolocation for  Algeria ,  Tazoult-Lambese
# Retrieve articles for  Algeria ,  Tazoult-Lambese
# Retrieve geolocation for  Algeria ,  Béchar
# Retrieve articles for  Algeria ,  Béchar
# Retrieve geolocation for  Algeria ,  Akbou
# Retrieve articles for  Algeria ,  Akbou
# Retrieve geolocation for  Algeria ,  Amizour
# Retrieve articles for  Algeria ,  Amizour
# Retrieve geolocation for  Algeria ,  Barbacha
# Retrieve articles for  Algeria ,  Barbacha
# Retrieve geolocation for  Algeria ,  Bejaïa
# Retrieve articles for  Algeria ,  Bejaïa
# Retrieve geolocation for  Algeria ,  el hed
# Retrieve articles for  Algeria ,  el hed
# Retrieve geolocation for  Algeria ,  El Kseur
# Retrieve articles for  Algeria ,  El Kseur
# Retrieve geolocation for  Algeria ,  Feraoun
# Retrieve articles for  Algeria ,  Feraoun
# Retrieve geolocation for  Algeria ,  Seddouk
# Retrieve articles for  Algeria ,  Seddouk
# Retrieve geolocation for  Algeria ,  Biskra
# Retrieve articles for  Algeria ,  Biskra
# Retrieve geolocation for  Algeria ,  Oumache
# Retrieve articles for  Algeria ,  Oumache
# Retrieve geolocation for  Algeria ,  Sidi Khaled
# Retrieve articles for  Algeria ,  Sidi Khaled
# Retrieve geolocation for  Algeria ,  Sidi Okba
# Retrieve articles for  Algeria ,  Sidi Okba
# Retrieve geolocation for  Algeria ,  Tolga
# Retrieve articles for  Algeria ,  Tolga
# Retrieve geolocation for  Algeria ,  Zeribet el Oued
# Retrieve articles for  Algeria ,  Zeribet el Oued
# Retrieve geolocation for  Algeria ,  Beni Mered
# Retrieve articles for  Algeria ,  Beni Mered
# Retrieve geolocation for  Algeria ,  Boû Arfa
# Retrieve articles for  Algeria ,  Boû Arfa
# Retrieve geolocation for  Algeria ,  Boufarik
# Retrieve articles for  Algeria ,  Boufarik
# Retrieve geolocation for  Algeria ,  Bouinan
# Retrieve articles for  Algeria ,  Bouinan
# Retrieve geolocation for  Algeria ,  Chebli
# Retrieve articles for  Algeria ,  Chebli
# Retrieve geolocation for  Algeria ,  Chiffa
# Retrieve articles for  Algeria ,  Chiffa
# Retrieve geolocation for  Algeria ,  Larbaâ
# Retrieve articles for  Algeria ,  Larbaâ
# Retrieve geolocation for  Algeria ,  Meftah
# Retrieve articles for  Algeria ,  Meftah
# Retrieve geolocation for  Algeria ,  Sidi Moussa
# Retrieve articles for  Algeria ,  Sidi Moussa
# Retrieve geolocation for  Algeria ,  Souma
# Retrieve articles for  Algeria ,  Souma
# Retrieve geolocation for  Algeria ,  Bordj Ghdir
# Retrieve articles for  Algeria ,  Bordj Ghdir
# Retrieve geolocation for  Algeria ,  Bordj Zemoura
# Retrieve articles for  Algeria ,  Bordj Zemoura
# Retrieve geolocation for  Algeria ,  El Achir
# Retrieve articles for  Algeria ,  El Achir
# Retrieve geolocation for  Algeria ,  Mansourah
# Retrieve articles for  Algeria ,  Mansourah
# Retrieve geolocation for  Algeria ,  Melouza
# Retrieve articles for  Algeria ,  Melouza
# Retrieve geolocation for  Algeria ,  Râs el Oued
# Retrieve articles for  Algeria ,  Râs el Oued
# Retrieve geolocation for  Algeria ,  Aïn Bessem
# Retrieve articles for  Algeria ,  Aïn Bessem
# Retrieve geolocation for  Algeria ,  Bouïra
# Retrieve articles for  Algeria ,  Bouïra
# Retrieve geolocation for  Algeria ,  Chorfa
# Retrieve articles for  Algeria ,  Chorfa
# Retrieve geolocation for  Algeria ,  Draa el Mizan
# Retrieve articles for  Algeria ,  Draa el Mizan
# Retrieve geolocation for  Algeria ,  Lakhdaria
# Retrieve articles for  Algeria ,  Lakhdaria
# Retrieve geolocation for  Algeria ,  Sour el Ghozlane
# Retrieve articles for  Algeria ,  Sour el Ghozlane
# Retrieve geolocation for  Algeria ,  Arbatache
# Retrieve articles for  Algeria ,  Arbatache
# Retrieve geolocation for  Algeria ,  Beni Amrane
# Retrieve articles for  Algeria ,  Beni Amrane
# Retrieve geolocation for  Algeria ,  Boudouaou
# Retrieve articles for  Algeria ,  Boudouaou
# Retrieve geolocation for  Algeria ,  Boumerdas
# Retrieve articles for  Algeria ,  Boumerdas
# Retrieve geolocation for  Algeria ,  Chabet el Ameur
# Retrieve articles for  Algeria ,  Chabet el Ameur
# Retrieve geolocation for  Algeria ,  Dellys
# Retrieve articles for  Algeria ,  Dellys
# Retrieve geolocation for  Algeria ,  Khemis el Khechna
# Retrieve articles for  Algeria ,  Khemis el Khechna
# Retrieve geolocation for  Algeria ,  Makouda
# Retrieve articles for  Algeria ,  Makouda
# Retrieve geolocation for  Algeria ,  Naciria
# Retrieve articles for  Algeria ,  Naciria
# Retrieve geolocation for  Algeria ,  Ouled Moussa
# Retrieve articles for  Algeria ,  Ouled Moussa
# Retrieve geolocation for  Algeria ,  Reghaïa
# Retrieve articles for  Algeria ,  Reghaïa
# Retrieve geolocation for  Algeria ,  Tadmaït
# Retrieve articles for  Algeria ,  Tadmaït
# Retrieve geolocation for  Algeria ,  Thenia
# Retrieve articles for  Algeria ,  Thenia
# Retrieve geolocation for  Algeria ,  Tizi Gheniff
# Retrieve articles for  Algeria ,  Tizi Gheniff
# Retrieve geolocation for  Algeria ,  Abou el Hassan
# Retrieve articles for  Algeria ,  Abou el Hassan
# Retrieve geolocation for  Algeria ,  Boukadir
# Retrieve articles for  Algeria ,  Boukadir
# Retrieve geolocation for  Algeria ,  Ech Chettia
# Retrieve articles for  Algeria ,  Ech Chettia
# Retrieve geolocation for  Algeria ,  Oued Fodda
# Retrieve articles for  Algeria ,  Oued Fodda
# Retrieve geolocation for  Algeria ,  Oued Sly
# Retrieve articles for  Algeria ,  Oued Sly
# Retrieve geolocation for  Algeria ,  Sidi Akkacha
# Retrieve articles for  Algeria ,  Sidi Akkacha
# Retrieve geolocation for  Algeria ,  ’Aïn Abid
# Retrieve articles for  Algeria ,  ’Aïn Abid
# Retrieve geolocation for  Algeria ,  Aïn Smara
# Retrieve articles for  Algeria ,  Aïn Smara
# Retrieve geolocation for  Algeria ,  Didouche Mourad
# Retrieve articles for  Algeria ,  Didouche Mourad
# Retrieve geolocation for  Algeria ,  El Khroub
# Retrieve articles for  Algeria ,  El Khroub
# Retrieve geolocation for  Algeria ,  Hamma Bouziane
# Retrieve articles for  Algeria ,  Hamma Bouziane
# Retrieve geolocation for  Algeria ,  ’Aïn el Bell
# Retrieve articles for  Algeria ,  ’Aïn el Bell
# Retrieve geolocation for  Algeria ,  Aïn Oussera
# Retrieve articles for  Algeria ,  Aïn Oussera
# Retrieve geolocation for  Algeria ,  Birine
# Retrieve articles for  Algeria ,  Birine
# Retrieve geolocation for  Algeria ,  Charef
# Retrieve articles for  Algeria ,  Charef
# Retrieve geolocation for  Algeria ,  Dar Chioukh
# Retrieve articles for  Algeria ,  Dar Chioukh
# Retrieve geolocation for  Algeria ,  El Idrissia
# Retrieve articles for  Algeria ,  El Idrissia
# Retrieve geolocation for  Algeria ,  Messaad
# Retrieve articles for  Algeria ,  Messaad
# Retrieve geolocation for  Algeria ,  Brezina
# Retrieve articles for  Algeria ,  Brezina
# Retrieve geolocation for  Algeria ,  El Abiodh Sidi Cheikh
# Retrieve articles for  Algeria ,  El Abiodh Sidi Cheikh
# Retrieve geolocation for  Algeria ,  El Bayadh
# Retrieve articles for  Algeria ,  El Bayadh
# Retrieve geolocation for  Algeria ,  Debila
# Retrieve articles for  Algeria ,  Debila
# Retrieve geolocation for  Algeria ,  El Oued
# Retrieve articles for  Algeria ,  El Oued
# Retrieve geolocation for  Algeria ,  Reguiba
# Retrieve articles for  Algeria ,  Reguiba
# Retrieve geolocation for  Algeria ,  Robbah
# Retrieve articles for  Algeria ,  Robbah
# Retrieve geolocation for  Algeria ,  Ben Mehidi
# Retrieve articles for  Algeria ,  Ben Mehidi
# Retrieve geolocation for  Algeria ,  Besbes
# Retrieve articles for  Algeria ,  Besbes
# Retrieve geolocation for  Algeria ,  El Kala
# Retrieve articles for  Algeria ,  El Kala
# Retrieve geolocation for  Algeria ,  Berriane
# Retrieve articles for  Algeria ,  Berriane
# Retrieve geolocation for  Algeria ,  Ghardaïa
# Retrieve articles for  Algeria ,  Ghardaïa
# Retrieve geolocation for  Algeria ,  Metlili Chaamba
# Retrieve articles for  Algeria ,  Metlili Chaamba
# Retrieve geolocation for  Algeria ,  Boumahra Ahmed
# Retrieve articles for  Algeria ,  Boumahra Ahmed
# Retrieve geolocation for  Algeria ,  Guelma
# Retrieve articles for  Algeria ,  Guelma
# Retrieve geolocation for  Algeria ,  Héliopolis
# Retrieve articles for  Algeria ,  Héliopolis
# Retrieve geolocation for  Algeria ,  Khenchela
# Retrieve articles for  Algeria ,  Khenchela
# Retrieve geolocation for  Algeria ,  Aflou
# Retrieve articles for  Algeria ,  Aflou
# Retrieve geolocation for  Algeria ,  ‘Aïn el Hadjel
# Retrieve articles for  Algeria ,  ‘Aïn el Hadjel
# Retrieve geolocation for  Algeria ,  ’Aïn el Melh
# Retrieve articles for  Algeria ,  ’Aïn el Melh
# Retrieve geolocation for  Algeria ,  M’Sila
# Retrieve articles for  Algeria ,  M’Sila
# Retrieve geolocation for  Algeria ,  Sidi Aïssa
# Retrieve articles for  Algeria ,  Sidi Aïssa
# Retrieve geolocation for  Algeria ,  Bou Hanifia el Hamamat
# Retrieve articles for  Algeria ,  Bou Hanifia el Hamamat
# Retrieve geolocation for  Algeria ,  Mascara
# Retrieve articles for  Algeria ,  Mascara
# Retrieve geolocation for  Algeria ,  Oued el Abtal
# Retrieve articles for  Algeria ,  Oued el Abtal
# Retrieve geolocation for  Algeria ,  Sig
# Retrieve articles for  Algeria ,  Sig
# Retrieve geolocation for  Algeria ,  ’Aïn Boucif
# Retrieve articles for  Algeria ,  ’Aïn Boucif
# Retrieve geolocation for  Algeria ,  Berrouaghia
# Retrieve articles for  Algeria ,  Berrouaghia
# Retrieve geolocation for  Algeria ,  Ksar el Boukhari
# Retrieve articles for  Algeria ,  Ksar el Boukhari
# Retrieve geolocation for  Algeria ,  Médéa
# Retrieve articles for  Algeria ,  Médéa
# Retrieve geolocation for  Algeria ,  Chelghoum el Aïd
# Retrieve articles for  Algeria ,  Chelghoum el Aïd
# Retrieve geolocation for  Algeria ,  Mila
# Retrieve articles for  Algeria ,  Mila
# Retrieve geolocation for  Algeria ,  Rouached
# Retrieve articles for  Algeria ,  Rouached
# Retrieve geolocation for  Algeria ,  Sidi Mérouane
# Retrieve articles for  Algeria ,  Sidi Mérouane
# Retrieve geolocation for  Algeria ,  Telerghma
# Retrieve articles for  Algeria ,  Telerghma
# Retrieve geolocation for  Algeria ,  Mostaganem
# Retrieve articles for  Algeria ,  Mostaganem
# Retrieve geolocation for  Algeria ,  Aïn Sefra
# Retrieve articles for  Algeria ,  Aïn Sefra
# Retrieve geolocation for  Algeria ,  Naama
# Retrieve articles for  Algeria ,  Naama
# Retrieve geolocation for  Algeria ,  ’Aïn el Turk
# Retrieve articles for  Algeria ,  ’Aïn el Turk
# Retrieve geolocation for  Algeria ,  Aïn el Bya
# Retrieve articles for  Algeria ,  Aïn el Bya
# Retrieve geolocation for  Algeria ,  Bir el Djir
# Retrieve articles for  Algeria ,  Bir el Djir
# Retrieve geolocation for  Algeria ,  Bou Tlelis
# Retrieve articles for  Algeria ,  Bou Tlelis
# Retrieve geolocation for  Algeria ,  Es Senia
# Retrieve articles for  Algeria ,  Es Senia
# Retrieve geolocation for  Algeria ,  Mers el Kebir
# Retrieve articles for  Algeria ,  Mers el Kebir
# Retrieve geolocation for  Algeria ,  Sidi ech Chahmi
# Retrieve articles for  Algeria ,  Sidi ech Chahmi
# Retrieve geolocation for  Algeria ,  Djamaa
# Retrieve articles for  Algeria ,  Djamaa
# Retrieve geolocation for  Algeria ,  El Hadjira
# Retrieve articles for  Algeria ,  El Hadjira
# Retrieve geolocation for  Algeria ,  Hassi Messaoud
# Retrieve articles for  Algeria ,  Hassi Messaoud
# Retrieve geolocation for  Algeria ,  Megarine
# Retrieve articles for  Algeria ,  Megarine
# Retrieve geolocation for  Algeria ,  Rouissat
# Retrieve articles for  Algeria ,  Rouissat
# Retrieve geolocation for  Algeria ,  Sidi Amrane
# Retrieve articles for  Algeria ,  Sidi Amrane
# Retrieve geolocation for  Algeria ,  Tebesbest
# Retrieve articles for  Algeria ,  Tebesbest
# Retrieve geolocation for  Algeria ,  Touggourt
# Retrieve articles for  Algeria ,  Touggourt
# Retrieve geolocation for  Algeria ,  Aïn Beïda
# Retrieve articles for  Algeria ,  Aïn Beïda
# Retrieve geolocation for  Algeria ,  Aïn Fakroun
# Retrieve articles for  Algeria ,  Aïn Fakroun
# Retrieve geolocation for  Algeria ,  Aïn Kercha
# Retrieve articles for  Algeria ,  Aïn Kercha
# Retrieve geolocation for  Algeria ,  El Aouinet
# Retrieve articles for  Algeria ,  El Aouinet
# Retrieve geolocation for  Algeria ,  Meskiana
# Retrieve articles for  Algeria ,  Meskiana
# Retrieve geolocation for  Algeria ,  Oum el Bouaghi
# Retrieve articles for  Algeria ,  Oum el Bouaghi
# Retrieve geolocation for  Algeria ,  ’Aïn Merane
# Retrieve articles for  Algeria ,  ’Aïn Merane
# Retrieve geolocation for  Algeria ,  Ammi Moussa
# Retrieve articles for  Algeria ,  Ammi Moussa
# Retrieve geolocation for  Algeria ,  Djidiouia
# Retrieve articles for  Algeria ,  Djidiouia
# Retrieve geolocation for  Algeria ,  Mazouna
# Retrieve articles for  Algeria ,  Mazouna
# Retrieve geolocation for  Algeria ,  Oued Rhiou
# Retrieve articles for  Algeria ,  Oued Rhiou
# Retrieve geolocation for  Algeria ,  Smala
# Retrieve articles for  Algeria ,  Smala
# Retrieve geolocation for  Algeria ,  Zemoura
# Retrieve articles for  Algeria ,  Zemoura
# Retrieve geolocation for  Algeria ,  ’Aïn el Hadjar
# Retrieve articles for  Algeria ,  ’Aïn el Hadjar
# Retrieve geolocation for  Algeria ,  Saïda
# Retrieve articles for  Algeria ,  Saïda
# Retrieve geolocation for  Algeria ,  Aïn Arnat
# Retrieve articles for  Algeria ,  Aïn Arnat
# Retrieve geolocation for  Algeria ,  BABOR - VILLE
# Retrieve articles for  Algeria ,  BABOR - VILLE
# Retrieve geolocation for  Algeria ,  Bougaa
# Retrieve articles for  Algeria ,  Bougaa
# Retrieve geolocation for  Algeria ,  El Eulma
# Retrieve articles for  Algeria ,  El Eulma
# Retrieve geolocation for  Algeria ,  Salah Bey
# Retrieve articles for  Algeria ,  Salah Bey
# Retrieve geolocation for  Algeria ,  Sétif
# Retrieve articles for  Algeria ,  Sétif
# Retrieve geolocation for  Algeria ,  Azzaba
# Retrieve articles for  Algeria ,  Azzaba
# Retrieve geolocation for  Algeria ,  Karkira
# Retrieve articles for  Algeria ,  Karkira
# Retrieve geolocation for  Algeria ,  Skikda
# Retrieve articles for  Algeria ,  Skikda
# Retrieve geolocation for  Algeria ,  Tamalous
# Retrieve articles for  Algeria ,  Tamalous
# Retrieve geolocation for  Algeria ,  Sedrata
# Retrieve articles for  Algeria ,  Sedrata
# Retrieve geolocation for  Algeria ,  I-n-Salah
# Retrieve articles for  Algeria ,  I-n-Salah
# Retrieve geolocation for  Algeria ,  Tamanrasset
# Retrieve articles for  Algeria ,  Tamanrasset
# Retrieve geolocation for  Algeria ,  Bir el Ater
# Retrieve articles for  Algeria ,  Bir el Ater
# Retrieve geolocation for  Algeria ,  Cheria
# Retrieve articles for  Algeria ,  Cheria
# Retrieve geolocation for  Algeria ,  Hammamet
# Retrieve articles for  Algeria ,  Hammamet
# Retrieve geolocation for  Algeria ,  Tébessa
# Retrieve articles for  Algeria ,  Tébessa
# Retrieve geolocation for  Algeria ,  ’Aïn Deheb
# Retrieve articles for  Algeria ,  ’Aïn Deheb
# Retrieve geolocation for  Algeria ,  Djebilet Rosfa
# Retrieve articles for  Algeria ,  Djebilet Rosfa
# Retrieve geolocation for  Algeria ,  Frenda
# Retrieve articles for  Algeria ,  Frenda
# Retrieve geolocation for  Algeria ,  Ksar Chellala
# Retrieve articles for  Algeria ,  Ksar Chellala
# Retrieve geolocation for  Algeria ,  Mehdia daira de meghila
# Retrieve articles for  Algeria ,  Mehdia daira de meghila
# Retrieve geolocation for  Algeria ,  Sougueur
# Retrieve articles for  Algeria ,  Sougueur
# Retrieve geolocation for  Algeria ,  Tindouf
# Retrieve articles for  Algeria ,  Tindouf
# Retrieve geolocation for  Algeria ,  ’Aïn Benian
# Retrieve articles for  Algeria ,  ’Aïn Benian
# Retrieve geolocation for  Algeria ,  Baraki
# Retrieve articles for  Algeria ,  Baraki
# Retrieve geolocation for  Algeria ,  Bou Ismaïl
# Retrieve articles for  Algeria ,  Bou Ismaïl
# Retrieve geolocation for  Algeria ,  Douera
# Retrieve articles for  Algeria ,  Douera
# Retrieve geolocation for  Algeria ,  El Affroun
# Retrieve articles for  Algeria ,  El Affroun
# Retrieve geolocation for  Algeria ,  Hadjout
# Retrieve articles for  Algeria ,  Hadjout
# Retrieve geolocation for  Algeria ,  Kolea
# Retrieve articles for  Algeria ,  Kolea
# Retrieve geolocation for  Algeria ,  Mouzaïa
# Retrieve articles for  Algeria ,  Mouzaïa
# Retrieve geolocation for  Algeria ,  Oued el Alleug
# Retrieve articles for  Algeria ,  Oued el Alleug
# Retrieve geolocation for  Algeria ,  Saoula
# Retrieve articles for  Algeria ,  Saoula
# Retrieve geolocation for  Algeria ,  Tipasa
# Retrieve articles for  Algeria ,  Tipasa
# Retrieve geolocation for  Algeria ,  Zeralda
# Retrieve articles for  Algeria ,  Zeralda
# Retrieve geolocation for  Algeria ,  Lardjem
# Retrieve articles for  Algeria ,  Lardjem
# Retrieve geolocation for  Algeria ,  ’Aïn el Hammam
# Retrieve articles for  Algeria ,  ’Aïn el Hammam
# Retrieve geolocation for  Algeria ,  Arhribs
# Retrieve articles for  Algeria ,  Arhribs
# Retrieve geolocation for  Algeria ,  Beni Douala
# Retrieve articles for  Algeria ,  Beni Douala
# Retrieve geolocation for  Algeria ,  Boghni
# Retrieve articles for  Algeria ,  Boghni
# Retrieve geolocation for  Algeria ,  Boudjima
# Retrieve articles for  Algeria ,  Boudjima
# Retrieve geolocation for  Algeria ,  Chemini
# Retrieve articles for  Algeria ,  Chemini
# Retrieve geolocation for  Algeria ,  Draa Ben Khedda
# Retrieve articles for  Algeria ,  Draa Ben Khedda
# Retrieve geolocation for  Algeria ,  Freha
# Retrieve articles for  Algeria ,  Freha
# Retrieve geolocation for  Algeria ,  Ighram
# Retrieve articles for  Algeria ,  Ighram
# Retrieve geolocation for  Algeria ,  L’Arbaa Naït Irathen
# Retrieve articles for  Algeria ,  L’Arbaa Naït Irathen
# Retrieve geolocation for  Algeria ,  Mekla
# Retrieve articles for  Algeria ,  Mekla
# Retrieve geolocation for  Algeria ,  Timizart
# Retrieve articles for  Algeria ,  Timizart
# Retrieve geolocation for  Algeria ,  Tirmitine
# Retrieve articles for  Algeria ,  Tirmitine
# Retrieve geolocation for  Algeria ,  Tizi Rached
# Retrieve articles for  Algeria ,  Tizi Rached
# Retrieve geolocation for  Algeria ,  Tizi-n-Tleta
# Retrieve articles for  Algeria ,  Tizi-n-Tleta
# Retrieve geolocation for  Algeria ,  Beni Mester
# Retrieve articles for  Algeria ,  Beni Mester
# Retrieve geolocation for  Algeria ,  Bensekrane
# Retrieve articles for  Algeria ,  Bensekrane
# Retrieve geolocation for  Algeria ,  Chetouane
# Retrieve articles for  Algeria ,  Chetouane
# Retrieve geolocation for  Algeria ,  Hennaya
# Retrieve articles for  Algeria ,  Hennaya
# Retrieve geolocation for  Algeria ,  Mansoûra
# Retrieve articles for  Algeria ,  Mansoûra
# Retrieve geolocation for  Algeria ,  Nedroma
# Retrieve articles for  Algeria ,  Nedroma
# Retrieve geolocation for  Algeria ,  Ouled Mimoun
# Retrieve articles for  Algeria ,  Ouled Mimoun
# Retrieve geolocation for  Algeria ,  Remchi
# Retrieve articles for  Algeria ,  Remchi
# Retrieve geolocation for  Algeria ,  Sebdou
# Retrieve articles for  Algeria ,  Sebdou
# Retrieve geolocation for  Algeria ,  Sidi Abdelli
# Retrieve articles for  Algeria ,  Sidi Abdelli
# Retrieve geolocation for  Algeria ,  Sidi Senoussi سيدي سنوسي
# Retrieve articles for  Algeria ,  Sidi Senoussi سيدي سنوسي
# Retrieve geolocation for  Egypt ,  Abu Hammad
# Retrieve articles for  Egypt ,  Abu Hammad
# Retrieve geolocation for  Egypt ,  Al Mahallah al Kubra
# Retrieve articles for  Egypt ,  Al Mahallah al Kubra
# Retrieve geolocation for  Egypt ,  Al Mansurah
# Retrieve articles for  Egypt ,  Al Mansurah
# Retrieve geolocation for  Egypt ,  Al Marj
# Retrieve articles for  Egypt ,  Al Marj
# Retrieve geolocation for  Egypt ,  Alexandria
# Retrieve articles for  Egypt ,  Alexandria
# Retrieve geolocation for  Egypt ,  Almazah
# Retrieve articles for  Egypt ,  Almazah
# Retrieve geolocation for  Egypt ,  Ar Rawdah
# Retrieve articles for  Egypt ,  Ar Rawdah
# Retrieve geolocation for  Egypt ,  Assiut
# Retrieve articles for  Egypt ,  Assiut
# Retrieve geolocation for  Egypt ,  Az Zamalik
# Retrieve articles for  Egypt ,  Az Zamalik
# Retrieve geolocation for  Egypt ,  Badr
# Retrieve articles for  Egypt ,  Badr
# Retrieve geolocation for  Egypt ,  Banha
# Retrieve articles for  Egypt ,  Banha
# Retrieve geolocation for  Egypt ,  Bani Suwayf
# Retrieve articles for  Egypt ,  Bani Suwayf
# Retrieve geolocation for  Egypt ,  Cairo
# Retrieve articles for  Egypt ,  Cairo
# Retrieve geolocation for  Egypt ,  Damietta
# Retrieve articles for  Egypt ,  Damietta
# Retrieve geolocation for  Egypt ,  Faraskur
# Retrieve articles for  Egypt ,  Faraskur
# Retrieve geolocation for  Egypt ,  Flaminj
# Retrieve articles for  Egypt ,  Flaminj
# Retrieve geolocation for  Egypt ,  Giza
# Retrieve articles for  Egypt ,  Giza
# Retrieve geolocation for  Egypt ,  Heliopolis
# Retrieve articles for  Egypt ,  Heliopolis
# Retrieve geolocation for  Egypt ,  Helwan
# Retrieve articles for  Egypt ,  Helwan
# Retrieve geolocation for  Egypt ,  Hurghada
# Retrieve articles for  Egypt ,  Hurghada
# Retrieve geolocation for  Egypt ,  Ismailia
# Retrieve articles for  Egypt ,  Ismailia
# Retrieve geolocation for  Egypt ,  Kafr ash Shaykh
# Retrieve articles for  Egypt ,  Kafr ash Shaykh
# Retrieve geolocation for  Egypt ,  Luxor
# Retrieve articles for  Egypt ,  Luxor
# Retrieve geolocation for  Egypt ,  Madinat an Nasr
# Retrieve articles for  Egypt ,  Madinat an Nasr
# Retrieve geolocation for  Egypt ,  Madinat as Sadis min Uktubar
# Retrieve articles for  Egypt ,  Madinat as Sadis min Uktubar
# Retrieve geolocation for  Egypt ,  Minya
# Retrieve articles for  Egypt ,  Minya
# Retrieve geolocation for  Egypt ,  Nasr
# Retrieve articles for  Egypt ,  Nasr
# Retrieve geolocation for  Egypt ,  New Cairo
# Retrieve articles for  Egypt ,  New Cairo
# Retrieve geolocation for  Egypt ,  Port Said
# Retrieve articles for  Egypt ,  Port Said
# Retrieve geolocation for  Egypt ,  Rafah
# Retrieve articles for  Egypt ,  Rafah
# Retrieve geolocation for  Egypt ,  Ramsis
# Retrieve articles for  Egypt ,  Ramsis
# Retrieve geolocation for  Egypt ,  Sadat
# Retrieve articles for  Egypt ,  Sadat
# Retrieve geolocation for  Egypt ,  Shirbin
# Retrieve articles for  Egypt ,  Shirbin
# Retrieve geolocation for  Egypt ,  Shubra
# Retrieve articles for  Egypt ,  Shubra
# Retrieve geolocation for  Egypt ,  Sohag
# Retrieve articles for  Egypt ,  Sohag
# Retrieve geolocation for  Egypt ,  Suez
# Retrieve articles for  Egypt ,  Suez
# Retrieve geolocation for  Egypt ,  Tanta
# Retrieve articles for  Egypt ,  Tanta
# Retrieve geolocation for  Egypt ,  Toukh
# Retrieve articles for  Egypt ,  Toukh
# Retrieve geolocation for  Egypt ,  Zagazig
# Retrieve articles for  Egypt ,  Zagazig
# Retrieve geolocation for  Egypt ,  Abu Simbel
# Retrieve articles for  Egypt ,  Abu Simbel
# Retrieve geolocation for  Egypt ,  Aswan
# Retrieve articles for  Egypt ,  Aswan
# Retrieve geolocation for  Egypt ,  Idfū
# Retrieve articles for  Egypt ,  Idfū
# Retrieve geolocation for  Egypt ,  Kawm Umbū
# Retrieve articles for  Egypt ,  Kawm Umbū
# Retrieve geolocation for  Egypt ,  Abnūb
# Retrieve articles for  Egypt ,  Abnūb
# Retrieve geolocation for  Egypt ,  Abū Tīj
# Retrieve articles for  Egypt ,  Abū Tīj
# Retrieve geolocation for  Egypt ,  Al Badārī
# Retrieve articles for  Egypt ,  Al Badārī
# Retrieve geolocation for  Egypt ,  Al Qūşīyah
# Retrieve articles for  Egypt ,  Al Qūşīyah
# Retrieve geolocation for  Egypt ,  Asyūţ
# Retrieve articles for  Egypt ,  Asyūţ
# Retrieve geolocation for  Egypt ,  Dayrūţ
# Retrieve articles for  Egypt ,  Dayrūţ
# Retrieve geolocation for  Egypt ,  Manfalūţ
# Retrieve articles for  Egypt ,  Manfalūţ
# Retrieve geolocation for  Egypt ,  Abū al Maţāmīr
# Retrieve articles for  Egypt ,  Abū al Maţāmīr
# Retrieve geolocation for  Egypt ,  Ad Dilinjāt
# Retrieve articles for  Egypt ,  Ad Dilinjāt
# Retrieve geolocation for  Egypt ,  Damanhūr
# Retrieve articles for  Egypt ,  Damanhūr
# Retrieve geolocation for  Egypt ,  Ḩawsh ‘Īsá
# Retrieve articles for  Egypt ,  Ḩawsh ‘Īsá
# Retrieve geolocation for  Egypt ,  Idkū
# Retrieve articles for  Egypt ,  Idkū
# Retrieve geolocation for  Egypt ,  Kafr ad Dawwār
# Retrieve articles for  Egypt ,  Kafr ad Dawwār
# Retrieve geolocation for  Egypt ,  Kawm Ḩamādah
# Retrieve articles for  Egypt ,  Kawm Ḩamādah
# Retrieve geolocation for  Egypt ,  Rosetta
# Retrieve articles for  Egypt ,  Rosetta
# Retrieve geolocation for  Egypt ,  Al Fashn
# Retrieve articles for  Egypt ,  Al Fashn
# Retrieve geolocation for  Egypt ,  Banī Suwayf
# Retrieve articles for  Egypt ,  Banī Suwayf
# Retrieve geolocation for  Egypt ,  Būsh
# Retrieve articles for  Egypt ,  Būsh
# Retrieve geolocation for  Egypt ,  Sumusţā as Sulţānī
# Retrieve articles for  Egypt ,  Sumusţā as Sulţānī
# Retrieve geolocation for  Egypt ,  Ḩalwān
# Retrieve articles for  Egypt ,  Ḩalwān
# Retrieve geolocation for  Egypt ,  ‘Izbat al Burj
# Retrieve articles for  Egypt ,  ‘Izbat al Burj
# Retrieve geolocation for  Egypt ,  Ajā
# Retrieve articles for  Egypt ,  Ajā
# Retrieve geolocation for  Egypt ,  Al Jammālīyah
# Retrieve articles for  Egypt ,  Al Jammālīyah
# Retrieve geolocation for  Egypt ,  Al Manşūrah
# Retrieve articles for  Egypt ,  Al Manşūrah
# Retrieve geolocation for  Egypt ,  Al Manzalah
# Retrieve articles for  Egypt ,  Al Manzalah
# Retrieve geolocation for  Egypt ,  Al Maţarīyah
# Retrieve articles for  Egypt ,  Al Maţarīyah
# Retrieve geolocation for  Egypt ,  Bilqās
# Retrieve articles for  Egypt ,  Bilqās
# Retrieve geolocation for  Egypt ,  Dikirnis
# Retrieve articles for  Egypt ,  Dikirnis
# Retrieve geolocation for  Egypt ,  Minyat an Naşr
# Retrieve articles for  Egypt ,  Minyat an Naşr
# Retrieve geolocation for  Egypt ,  Shirbīn
# Retrieve articles for  Egypt ,  Shirbīn
# Retrieve geolocation for  Egypt ,  Ţalkhā
# Retrieve articles for  Egypt ,  Ţalkhā
# Retrieve geolocation for  Egypt ,  Az Zarqā
# Retrieve articles for  Egypt ,  Az Zarqā
# Retrieve geolocation for  Egypt ,  Fāraskūr
# Retrieve articles for  Egypt ,  Fāraskūr
# Retrieve geolocation for  Egypt ,  Al Fayyūm
# Retrieve articles for  Egypt ,  Al Fayyūm
# Retrieve geolocation for  Egypt ,  Al Wāsiţah
# Retrieve articles for  Egypt ,  Al Wāsiţah
# Retrieve geolocation for  Egypt ,  Ibshawāy
# Retrieve articles for  Egypt ,  Ibshawāy
# Retrieve geolocation for  Egypt ,  Iţsā
# Retrieve articles for  Egypt ,  Iţsā
# Retrieve geolocation for  Egypt ,  Ţāmiyah
# Retrieve articles for  Egypt ,  Ţāmiyah
# Retrieve geolocation for  Egypt ,  Al Maḩallah al Kubrá
# Retrieve articles for  Egypt ,  Al Maḩallah al Kubrá
# Retrieve geolocation for  Egypt ,  Basyūn
# Retrieve articles for  Egypt ,  Basyūn
# Retrieve geolocation for  Egypt ,  Kafr az Zayyāt
# Retrieve articles for  Egypt ,  Kafr az Zayyāt
# Retrieve geolocation for  Egypt ,  Quţūr
# Retrieve articles for  Egypt ,  Quţūr
# Retrieve geolocation for  Egypt ,  Samannūd
# Retrieve articles for  Egypt ,  Samannūd
# Retrieve geolocation for  Egypt ,  Tanda
# Retrieve articles for  Egypt ,  Tanda
# Retrieve geolocation for  Egypt ,  Zefta
# Retrieve articles for  Egypt ,  Zefta
# Retrieve geolocation for  Egypt ,  Al ‘Ayyāţ
# Retrieve articles for  Egypt ,  Al ‘Ayyāţ
# Retrieve geolocation for  Egypt ,  Al Bawīţī
# Retrieve articles for  Egypt ,  Al Bawīţī
# Retrieve geolocation for  Egypt ,  Al Ḩawāmidīyah
# Retrieve articles for  Egypt ,  Al Ḩawāmidīyah
# Retrieve geolocation for  Egypt ,  Aş Şaff
# Retrieve articles for  Egypt ,  Aş Şaff
# Retrieve geolocation for  Egypt ,  Awsīm
# Retrieve articles for  Egypt ,  Awsīm
# Retrieve geolocation for  Egypt ,  Madīnat Sittah Uktūbar
# Retrieve articles for  Egypt ,  Madīnat Sittah Uktūbar
# Retrieve geolocation for  Egypt ,  Al Ḩāmūl
# Retrieve articles for  Egypt ,  Al Ḩāmūl
# Retrieve geolocation for  Egypt ,  Disūq
# Retrieve articles for  Egypt ,  Disūq
# Retrieve geolocation for  Egypt ,  Fuwwah
# Retrieve articles for  Egypt ,  Fuwwah
# Retrieve geolocation for  Egypt ,  Markaz Disūq
# Retrieve articles for  Egypt ,  Markaz Disūq
# Retrieve geolocation for  Egypt ,  Munshāt ‘Alī Āghā
# Retrieve articles for  Egypt ,  Munshāt ‘Alī Āghā
# Retrieve geolocation for  Egypt ,  Sīdī Sālim
# Retrieve articles for  Egypt ,  Sīdī Sālim
# Retrieve geolocation for  Egypt ,  Markaz al Uqşur
# Retrieve articles for  Egypt ,  Markaz al Uqşur
# Retrieve geolocation for  Egypt ,  Al ‘Alamayn
# Retrieve articles for  Egypt ,  Al ‘Alamayn
# Retrieve geolocation for  Egypt ,  Mersa Matruh
# Retrieve articles for  Egypt ,  Mersa Matruh
# Retrieve geolocation for  Egypt ,  Siwa Oasis
# Retrieve articles for  Egypt ,  Siwa Oasis
# Retrieve geolocation for  Egypt ,  Abū Qurqāş
# Retrieve articles for  Egypt ,  Abū Qurqāş
# Retrieve geolocation for  Egypt ,  Al Minyā
# Retrieve articles for  Egypt ,  Al Minyā
# Retrieve geolocation for  Egypt ,  Banī Mazār
# Retrieve articles for  Egypt ,  Banī Mazār
# Retrieve geolocation for  Egypt ,  Dayr Mawās
# Retrieve articles for  Egypt ,  Dayr Mawās
# Retrieve geolocation for  Egypt ,  Mallawī
# Retrieve articles for  Egypt ,  Mallawī
# Retrieve geolocation for  Egypt ,  Maţāy
# Retrieve articles for  Egypt ,  Maţāy
# Retrieve geolocation for  Egypt ,  Samālūţ
# Retrieve articles for  Egypt ,  Samālūţ
# Retrieve geolocation for  Egypt ,  Al Bājūr
# Retrieve articles for  Egypt ,  Al Bājūr
# Retrieve geolocation for  Egypt ,  Ash Shuhadā’
# Retrieve articles for  Egypt ,  Ash Shuhadā’
# Retrieve geolocation for  Egypt ,  Ashmūn
# Retrieve articles for  Egypt ,  Ashmūn
# Retrieve geolocation for  Egypt ,  Munūf
# Retrieve articles for  Egypt ,  Munūf
# Retrieve geolocation for  Egypt ,  Quwaysinā
# Retrieve articles for  Egypt ,  Quwaysinā
# Retrieve geolocation for  Egypt ,  Shibīn al Kawm
# Retrieve articles for  Egypt ,  Shibīn al Kawm
# Retrieve geolocation for  Egypt ,  Talā
# Retrieve articles for  Egypt ,  Talā
# Retrieve geolocation for  Egypt ,  Al Khārijah
# Retrieve articles for  Egypt ,  Al Khārijah
# Retrieve geolocation for  Egypt ,  Qaşr al Farāfirah
# Retrieve articles for  Egypt ,  Qaşr al Farāfirah
# Retrieve geolocation for  Egypt ,  Arish
# Retrieve articles for  Egypt ,  Arish
# Retrieve geolocation for  Egypt ,  Al Khānkah
# Retrieve articles for  Egypt ,  Al Khānkah
# Retrieve geolocation for  Egypt ,  Al Qanāţir al Khayrīyah
# Retrieve articles for  Egypt ,  Al Qanāţir al Khayrīyah
# Retrieve geolocation for  Egypt ,  Banhā
# Retrieve articles for  Egypt ,  Banhā
# Retrieve geolocation for  Egypt ,  Qalyūb
# Retrieve articles for  Egypt ,  Qalyūb
# Retrieve geolocation for  Egypt ,  Shibīn al Qanāṭir
# Retrieve articles for  Egypt ,  Shibīn al Qanāṭir
# Retrieve geolocation for  Egypt ,  Dishnā
# Retrieve articles for  Egypt ,  Dishnā
# Retrieve geolocation for  Egypt ,  Farshūţ
# Retrieve articles for  Egypt ,  Farshūţ
# Retrieve geolocation for  Egypt ,  Isnā
# Retrieve articles for  Egypt ,  Isnā
# Retrieve geolocation for  Egypt ,  Kousa
# Retrieve articles for  Egypt ,  Kousa
# Retrieve geolocation for  Egypt ,  Naja' Ḥammādī
# Retrieve articles for  Egypt ,  Naja' Ḥammādī
# Retrieve geolocation for  Egypt ,  Qinā
# Retrieve articles for  Egypt ,  Qinā
# Retrieve geolocation for  Egypt ,  Al Quşayr
# Retrieve articles for  Egypt ,  Al Quşayr
# Retrieve geolocation for  Egypt ,  El Gouna
# Retrieve articles for  Egypt ,  El Gouna
# Retrieve geolocation for  Egypt ,  Makadi Bay
# Retrieve articles for  Egypt ,  Makadi Bay
# Retrieve geolocation for  Egypt ,  Marsa Alam
# Retrieve articles for  Egypt ,  Marsa Alam
# Retrieve geolocation for  Egypt ,  Ras Gharib
# Retrieve articles for  Egypt ,  Ras Gharib
# Retrieve geolocation for  Egypt ,  Safaga
# Retrieve articles for  Egypt ,  Safaga
# Retrieve geolocation for  Egypt ,  Akhmīm
# Retrieve articles for  Egypt ,  Akhmīm
# Retrieve geolocation for  Egypt ,  Al Balyanā
# Retrieve articles for  Egypt ,  Al Balyanā
# Retrieve geolocation for  Egypt ,  Al Manshāh
# Retrieve articles for  Egypt ,  Al Manshāh
# Retrieve geolocation for  Egypt ,  Jirjā
# Retrieve articles for  Egypt ,  Jirjā
# Retrieve geolocation for  Egypt ,  Juhaynah
# Retrieve articles for  Egypt ,  Juhaynah
# Retrieve geolocation for  Egypt ,  Markaz Jirjā
# Retrieve articles for  Egypt ,  Markaz Jirjā
# Retrieve geolocation for  Egypt ,  Markaz Sūhāj
# Retrieve articles for  Egypt ,  Markaz Sūhāj
# Retrieve geolocation for  Egypt ,  Ţahţā
# Retrieve articles for  Egypt ,  Ţahţā
# Retrieve geolocation for  Egypt ,  Dahab
# Retrieve articles for  Egypt ,  Dahab
# Retrieve geolocation for  Egypt ,  El-Tor
# Retrieve articles for  Egypt ,  El-Tor
# Retrieve geolocation for  Egypt ,  Nuwaybi‘a
# Retrieve articles for  Egypt ,  Nuwaybi‘a
# Retrieve geolocation for  Egypt ,  Saint Catherine
# Retrieve articles for  Egypt ,  Saint Catherine
# Retrieve geolocation for  Egypt ,  Sharm el-Sheikh
# Retrieve articles for  Egypt ,  Sharm el-Sheikh
# Retrieve geolocation for  Egypt ,  Ain Sukhna
# Retrieve articles for  Egypt ,  Ain Sukhna
# Retrieve geolocation for  Morocco ,  Afourer
# Retrieve articles for  Morocco ,  Afourer
# Retrieve geolocation for  Morocco ,  Agadir
# Retrieve articles for  Morocco ,  Agadir
# Retrieve geolocation for  Morocco ,  Ait Melloul
# Retrieve articles for  Morocco ,  Ait Melloul
# Retrieve geolocation for  Morocco ,  Al Hoceima
# Retrieve articles for  Morocco ,  Al Hoceima
# Retrieve geolocation for  Morocco ,  Assa
# Retrieve articles for  Morocco ,  Assa
# Retrieve geolocation for  Morocco ,  Benguerir
# Retrieve articles for  Morocco ,  Benguerir
# Retrieve geolocation for  Morocco ,  Beni Mellal
# Retrieve articles for  Morocco ,  Beni Mellal
# Retrieve geolocation for  Morocco ,  Berrechid
# Retrieve articles for  Morocco ,  Berrechid
# Retrieve geolocation for  Morocco ,  Casablanca
# Retrieve articles for  Morocco ,  Casablanca
# Retrieve geolocation for  Morocco ,  Deroua
# Retrieve articles for  Morocco ,  Deroua
# Retrieve geolocation for  Morocco ,  El Gara
# Retrieve articles for  Morocco ,  El Gara
# Retrieve geolocation for  Morocco ,  El Hajeb
# Retrieve articles for  Morocco ,  El Hajeb
# Retrieve geolocation for  Morocco ,  El Jadida
# Retrieve articles for  Morocco ,  El Jadida
# Retrieve geolocation for  Morocco ,  Erfoud
# Retrieve articles for  Morocco ,  Erfoud
# Retrieve geolocation for  Morocco ,  Fes
# Retrieve articles for  Morocco ,  Fes
# Retrieve geolocation for  Morocco ,  Fkih Ben Salah
# Retrieve articles for  Morocco ,  Fkih Ben Salah
# Retrieve geolocation for  Morocco ,  Kenitra
# Retrieve articles for  Morocco ,  Kenitra
# Retrieve geolocation for  Morocco ,  Khemisset
# Retrieve articles for  Morocco ,  Khemisset
# Retrieve geolocation for  Morocco ,  Khouribga
# Retrieve articles for  Morocco ,  Khouribga
# Retrieve geolocation for  Morocco ,  Ksar el Kebir
# Retrieve articles for  Morocco ,  Ksar el Kebir
# Retrieve geolocation for  Morocco ,  Larache
# Retrieve articles for  Morocco ,  Larache
# Retrieve geolocation for  Morocco ,  Mansour
# Retrieve articles for  Morocco ,  Mansour
# Retrieve geolocation for  Morocco ,  Marrakesh
# Retrieve articles for  Morocco ,  Marrakesh
# Retrieve geolocation for  Morocco ,  Mehediyah
# Retrieve articles for  Morocco ,  Mehediyah
# Retrieve geolocation for  Morocco ,  Meknes
# Retrieve articles for  Morocco ,  Meknes
# Retrieve geolocation for  Morocco ,  Mohammedia
# Retrieve articles for  Morocco ,  Mohammedia
# Retrieve geolocation for  Morocco ,  Nador
# Retrieve articles for  Morocco ,  Nador
# Retrieve geolocation for  Morocco ,  Ouazzane
# Retrieve articles for  Morocco ,  Ouazzane
# Retrieve geolocation for  Morocco ,  Oued Zem
# Retrieve articles for  Morocco ,  Oued Zem
# Retrieve geolocation for  Morocco ,  Oujda
# Retrieve articles for  Morocco ,  Oujda
# Retrieve geolocation for  Morocco ,  Oulad Teima
# Retrieve articles for  Morocco ,  Oulad Teima
# Retrieve geolocation for  Morocco ,  Rabat
# Retrieve articles for  Morocco ,  Rabat
# Retrieve geolocation for  Morocco ,  Safi
# Retrieve articles for  Morocco ,  Safi
# Retrieve geolocation for  Morocco ,  Sefrou
# Retrieve articles for  Morocco ,  Sefrou
# Retrieve geolocation for  Morocco ,  Settat
# Retrieve articles for  Morocco ,  Settat
# Retrieve geolocation for  Morocco ,  Sidi Bennour
# Retrieve articles for  Morocco ,  Sidi Bennour
# Retrieve geolocation for  Morocco ,  Sidi Slimane
# Retrieve articles for  Morocco ,  Sidi Slimane
# Retrieve geolocation for  Morocco ,  Skhirat
# Retrieve articles for  Morocco ,  Skhirat
# Retrieve geolocation for  Morocco ,  Tahala
# Retrieve articles for  Morocco ,  Tahala
# Retrieve geolocation for  Morocco ,  Tan-Tan
# Retrieve articles for  Morocco ,  Tan-Tan
# Retrieve geolocation for  Morocco ,  Tangier
# Retrieve articles for  Morocco ,  Tangier
# Retrieve geolocation for  Morocco ,  Tarfaya
# Retrieve articles for  Morocco ,  Tarfaya
# Retrieve geolocation for  Morocco ,  Taza
# Retrieve articles for  Morocco ,  Taza
# Retrieve geolocation for  Morocco ,  Temara
# Retrieve articles for  Morocco ,  Temara
# Retrieve geolocation for  Morocco ,  Tiflet
# Retrieve articles for  Morocco ,  Tiflet
# Retrieve geolocation for  Morocco ,  Tiznit
# Retrieve articles for  Morocco ,  Tiznit
# Retrieve geolocation for  Morocco ,  Touissite
# Retrieve articles for  Morocco ,  Touissite
# Retrieve geolocation for  Morocco ,  Agadir Melloul
# Retrieve articles for  Morocco ,  Agadir Melloul
# Retrieve geolocation for  Morocco ,  Agadir-Ida-ou-Tnan
# Retrieve articles for  Morocco ,  Agadir-Ida-ou-Tnan
# Retrieve geolocation for  Morocco ,  Aoulouz
# Retrieve articles for  Morocco ,  Aoulouz
# Retrieve geolocation for  Morocco ,  Aourir
# Retrieve articles for  Morocco ,  Aourir
# Retrieve geolocation for  Morocco ,  Arazane
# Retrieve articles for  Morocco ,  Arazane
# Retrieve geolocation for  Morocco ,  Argana
# Retrieve articles for  Morocco ,  Argana
# Retrieve geolocation for  Morocco ,  Bigoudine
# Retrieve articles for  Morocco ,  Bigoudine
# Retrieve geolocation for  Morocco ,  Chtouka-Ait-Baha
# Retrieve articles for  Morocco ,  Chtouka-Ait-Baha
# Retrieve geolocation for  Morocco ,  Inezgane
# Retrieve articles for  Morocco ,  Inezgane
# Retrieve geolocation for  Morocco ,  Inezgane-Ait Melloul
# Retrieve articles for  Morocco ,  Inezgane-Ait Melloul
# Retrieve geolocation for  Morocco ,  Ouijjane
# Retrieve articles for  Morocco ,  Ouijjane
# Retrieve geolocation for  Morocco ,  Oulad Teïma
# Retrieve articles for  Morocco ,  Oulad Teïma
# Retrieve geolocation for  Morocco ,  Reggada
# Retrieve articles for  Morocco ,  Reggada
# Retrieve geolocation for  Morocco ,  Sidi Ifni
# Retrieve articles for  Morocco ,  Sidi Ifni
# Retrieve geolocation for  Morocco ,  Tadrart
# Retrieve articles for  Morocco ,  Tadrart
# Retrieve geolocation for  Morocco ,  Tafraout
# Retrieve articles for  Morocco ,  Tafraout
# Retrieve geolocation for  Morocco ,  Taghazout
# Retrieve articles for  Morocco ,  Taghazout
# Retrieve geolocation for  Morocco ,  Taliouine
# Retrieve articles for  Morocco ,  Taliouine
# Retrieve geolocation for  Morocco ,  Tamri
# Retrieve articles for  Morocco ,  Tamri
# Retrieve geolocation for  Morocco ,  Tanalt
# Retrieve articles for  Morocco ,  Tanalt
# Retrieve geolocation for  Morocco ,  Taroudannt
# Retrieve articles for  Morocco ,  Taroudannt
# Retrieve geolocation for  Morocco ,  Taroudant
# Retrieve articles for  Morocco ,  Taroudant
# Retrieve geolocation for  Morocco ,  Tarsouat
# Retrieve articles for  Morocco ,  Tarsouat
# Retrieve geolocation for  Morocco ,  Tata
# Retrieve articles for  Morocco ,  Tata
# Retrieve geolocation for  Morocco ,  Azemmour
# Retrieve articles for  Morocco ,  Azemmour
# Retrieve geolocation for  Morocco ,  Benslimane
# Retrieve articles for  Morocco ,  Benslimane
# Retrieve geolocation for  Morocco ,  Berrechid Province
# Retrieve articles for  Morocco ,  Berrechid Province
# Retrieve geolocation for  Morocco ,  Boulaouane
# Retrieve articles for  Morocco ,  Boulaouane
# Retrieve geolocation for  Morocco ,  Bouskoura
# Retrieve articles for  Morocco ,  Bouskoura
# Retrieve geolocation for  Morocco ,  Bouznika
# Retrieve articles for  Morocco ,  Bouznika
# Retrieve geolocation for  Morocco ,  El Jadid
# Retrieve articles for  Morocco ,  El Jadid
# Retrieve geolocation for  Morocco ,  El-Jadida
# Retrieve articles for  Morocco ,  El-Jadida
# Retrieve geolocation for  Morocco ,  Mediouna
# Retrieve articles for  Morocco ,  Mediouna
# Retrieve geolocation for  Morocco ,  Nouaceur
# Retrieve articles for  Morocco ,  Nouaceur
# Retrieve geolocation for  Morocco ,  Oualidia
# Retrieve articles for  Morocco ,  Oualidia
# Retrieve geolocation for  Morocco ,  Oulad Frej
# Retrieve articles for  Morocco ,  Oulad Frej
# Retrieve geolocation for  Morocco ,  Settat Province
# Retrieve articles for  Morocco ,  Settat Province
# Retrieve geolocation for  Morocco ,  Sidi Smai’il
# Retrieve articles for  Morocco ,  Sidi Smai’il
# Retrieve geolocation for  Morocco ,  Tit Mellil
# Retrieve articles for  Morocco ,  Tit Mellil
# Retrieve geolocation for  Morocco ,  Zawyat an Nwaçer
# Retrieve articles for  Morocco ,  Zawyat an Nwaçer
# Retrieve geolocation for  Morocco ,  Agdz
# Retrieve articles for  Morocco ,  Agdz
# Retrieve geolocation for  Morocco ,  Alnif
# Retrieve articles for  Morocco ,  Alnif
# Retrieve geolocation for  Morocco ,  Aoufous
# Retrieve articles for  Morocco ,  Aoufous
# Retrieve geolocation for  Morocco ,  Arfoud
# Retrieve articles for  Morocco ,  Arfoud
# Retrieve geolocation for  Morocco ,  Errachidia
# Retrieve articles for  Morocco ,  Errachidia
# Retrieve geolocation for  Morocco ,  Imilchil
# Retrieve articles for  Morocco ,  Imilchil
# Retrieve geolocation for  Morocco ,  Jebel Tiskaouine
# Retrieve articles for  Morocco ,  Jebel Tiskaouine
# Retrieve geolocation for  Morocco ,  Jorf
# Retrieve articles for  Morocco ,  Jorf
# Retrieve geolocation for  Morocco ,  Kelaat Mgouna
# Retrieve articles for  Morocco ,  Kelaat Mgouna
# Retrieve geolocation for  Morocco ,  Mhamid
# Retrieve articles for  Morocco ,  Mhamid
# Retrieve geolocation for  Morocco ,  Midelt
# Retrieve articles for  Morocco ,  Midelt
# Retrieve geolocation for  Morocco ,  Ouarzazat
# Retrieve articles for  Morocco ,  Ouarzazat
# Retrieve geolocation for  Morocco ,  Ouarzazate
# Retrieve articles for  Morocco ,  Ouarzazate
# Retrieve geolocation for  Morocco ,  Reçani
# Retrieve articles for  Morocco ,  Reçani
# Retrieve geolocation for  Morocco ,  Taznakht
# Retrieve articles for  Morocco ,  Taznakht
# Retrieve geolocation for  Morocco ,  Telouet
# Retrieve articles for  Morocco ,  Telouet
# Retrieve geolocation for  Morocco ,  Tinghir
# Retrieve articles for  Morocco ,  Tinghir
# Retrieve geolocation for  Morocco ,  Tinghir Province
# Retrieve articles for  Morocco ,  Tinghir Province
# Retrieve geolocation for  Morocco ,  Zagora
# Retrieve articles for  Morocco ,  Zagora
# Retrieve geolocation for  Morocco ,  Aïn Leuh
# Retrieve articles for  Morocco ,  Aïn Leuh
# Retrieve geolocation for  Morocco ,  Aknoul
# Retrieve articles for  Morocco ,  Aknoul
# Retrieve geolocation for  Morocco ,  Almis Marmoucha
# Retrieve articles for  Morocco ,  Almis Marmoucha
# Retrieve geolocation for  Morocco ,  Azrou
# Retrieve articles for  Morocco ,  Azrou
# Retrieve geolocation for  Morocco ,  Bhalil
# Retrieve articles for  Morocco ,  Bhalil
# Retrieve geolocation for  Morocco ,  Bouarouss
# Retrieve articles for  Morocco ,  Bouarouss
# Retrieve geolocation for  Morocco ,  Boulemane
# Retrieve articles for  Morocco ,  Boulemane
# Retrieve geolocation for  Morocco ,  El-Hajeb
# Retrieve articles for  Morocco ,  El-Hajeb
# Retrieve geolocation for  Morocco ,  Fès
# Retrieve articles for  Morocco ,  Fès
# Retrieve geolocation for  Morocco ,  Fès al Bali
# Retrieve articles for  Morocco ,  Fès al Bali
# Retrieve geolocation for  Morocco ,  Galaz
# Retrieve articles for  Morocco ,  Galaz
# Retrieve geolocation for  Morocco ,  Ghouazi
# Retrieve articles for  Morocco ,  Ghouazi
# Retrieve geolocation for  Morocco ,  Guercif
# Retrieve articles for  Morocco ,  Guercif
# Retrieve geolocation for  Morocco ,  Ifrane
# Retrieve articles for  Morocco ,  Ifrane
# Retrieve geolocation for  Morocco ,  Meknès
# Retrieve articles for  Morocco ,  Meknès
# Retrieve geolocation for  Morocco ,  Missour
# ...
# Retrieve articles for  Tunisia ,  Er Regueb
# Retrieve geolocation for  Tunisia ,  Jilma
# Retrieve articles for  Tunisia ,  Jilma
# Retrieve geolocation for  Tunisia ,  Mezzouna
# Retrieve articles for  Tunisia ,  Mezzouna
# Retrieve geolocation for  Tunisia ,  Bou Arada
# Retrieve articles for  Tunisia ,  Bou Arada
# Retrieve geolocation for  Tunisia ,  Gafour
# Retrieve articles for  Tunisia ,  Gafour
# Retrieve geolocation for  Tunisia ,  Kesra
# Retrieve articles for  Tunisia ,  Kesra
# Retrieve geolocation for  Tunisia ,  Le Krib
# Retrieve articles for  Tunisia ,  Le Krib
# Retrieve geolocation for  Tunisia ,  Maktar
# Retrieve articles for  Tunisia ,  Maktar
# Retrieve geolocation for  Tunisia ,  Siliana
# Retrieve articles for  Tunisia ,  Siliana
# Retrieve geolocation for  Tunisia ,  Akouda
# Retrieve articles for  Tunisia ,  Akouda
# Retrieve geolocation for  Tunisia ,  Hammam Sousse
# Retrieve articles for  Tunisia ,  Hammam Sousse
# Retrieve geolocation for  Tunisia ,  Harqalah
# Retrieve articles for  Tunisia ,  Harqalah
# Retrieve geolocation for  Tunisia ,  Msaken
# Retrieve articles for  Tunisia ,  Msaken
# Retrieve geolocation for  Tunisia ,  Port el Kantaoui
# Retrieve articles for  Tunisia ,  Port el Kantaoui
# Retrieve geolocation for  Tunisia ,  Sidi Bou Ali
# Retrieve articles for  Tunisia ,  Sidi Bou Ali
# Retrieve geolocation for  Tunisia ,  Sidi el Hani
# Retrieve articles for  Tunisia ,  Sidi el Hani
# Retrieve geolocation for  Tunisia ,  Remada
# Retrieve articles for  Tunisia ,  Remada
# Retrieve geolocation for  Tunisia ,  Tataouine
# Retrieve articles for  Tunisia ,  Tataouine
# Retrieve geolocation for  Tunisia ,  Chebika
# Retrieve articles for  Tunisia ,  Chebika
# Retrieve geolocation for  Tunisia ,  Degache
# Retrieve articles for  Tunisia ,  Degache
# Retrieve geolocation for  Tunisia ,  Nefta
# Retrieve articles for  Tunisia ,  Nefta
# Retrieve geolocation for  Tunisia ,  Tamaghzah
# Retrieve articles for  Tunisia ,  Tamaghzah
# Retrieve geolocation for  Tunisia ,  Tozeur
# Retrieve articles for  Tunisia ,  Tozeur
# Retrieve geolocation for  Tunisia ,  Al Marsá
# Retrieve articles for  Tunisia ,  Al Marsá
# Retrieve geolocation for  Tunisia ,  Carthage
# Retrieve articles for  Tunisia ,  Carthage
# Retrieve geolocation for  Tunisia ,  La Goulette
# Retrieve articles for  Tunisia ,  La Goulette
# Retrieve geolocation for  Tunisia ,  La Mohammedia
# Retrieve articles for  Tunisia ,  La Mohammedia
# Retrieve geolocation for  Tunisia ,  Sidi Bou Saïd
# Retrieve articles for  Tunisia ,  Sidi Bou Saïd
# Retrieve geolocation for  Tunisia ,  El Fahs
# Retrieve articles for  Tunisia ,  El Fahs
# Retrieve geolocation for  Tunisia ,  Zaghouan
# Retrieve articles for  Tunisia ,  Zaghouan
# Retrieve geolocation for  Libya ,  Benghazi
# Retrieve articles for  Libya ,  Benghazi
# Retrieve geolocation for  Libya ,  Misratah
# Retrieve articles for  Libya ,  Misratah
# Retrieve geolocation for  Libya ,  Sabha
# Retrieve articles for  Libya ,  Sabha
# Retrieve geolocation for  Libya ,  Tripoli
# Retrieve articles for  Libya ,  Tripoli
# Retrieve geolocation for  Libya ,  Zliten
# Retrieve articles for  Libya ,  Zliten
# Retrieve geolocation for  Libya ,  Ajdabiya
# Retrieve articles for  Libya ,  Ajdabiya
# Retrieve geolocation for  Libya ,  Al Burayqah
# Retrieve articles for  Libya ,  Al Burayqah
# Retrieve geolocation for  Libya ,  Awjilah
# Retrieve articles for  Libya ,  Awjilah
# Retrieve geolocation for  Libya ,  Az Zuwaytīnah
# Retrieve articles for  Libya ,  Az Zuwaytīnah
# Retrieve geolocation for  Libya ,  Gialo
# Retrieve articles for  Libya ,  Gialo
# Retrieve geolocation for  Libya ,  Marādah
# Retrieve articles for  Libya ,  Marādah
# Retrieve geolocation for  Libya ,  Qaryat Sulūq
# Retrieve articles for  Libya ,  Qaryat Sulūq
# Retrieve geolocation for  Libya ,  Al Qubbah
# Retrieve articles for  Libya ,  Al Qubbah
# Retrieve geolocation for  Libya ,  Darnah
# Retrieve articles for  Libya ,  Darnah
# Retrieve geolocation for  Libya ,  Ghat
# Retrieve articles for  Libya ,  Ghat
# Retrieve geolocation for  Libya ,  Al Bayḑā’
# Retrieve articles for  Libya ,  Al Bayḑā’
# Retrieve geolocation for  Libya ,  Gharyan
# Retrieve articles for  Libya ,  Gharyan
# Retrieve geolocation for  Libya ,  Giado
# Retrieve articles for  Libya ,  Giado
# Retrieve geolocation for  Libya ,  Mizdah
# Retrieve articles for  Libya ,  Mizdah
# Retrieve geolocation for  Libya ,  Yafran
# Retrieve articles for  Libya ,  Yafran
# Retrieve geolocation for  Libya ,  Zintan
# Retrieve articles for  Libya ,  Zintan
# Retrieve geolocation for  Libya ,  Al ‘Azīzīyah
# Retrieve articles for  Libya ,  Al ‘Azīzīyah
# Retrieve geolocation for  Libya ,  Hūn
# Retrieve articles for  Libya ,  Hūn
# Retrieve geolocation for  Libya ,  Waddān
# Retrieve articles for  Libya ,  Waddān
# Retrieve geolocation for  Libya ,  Al Jawf
# Retrieve articles for  Libya ,  Al Jawf
# Retrieve geolocation for  Libya ,  At Tāj
# Retrieve articles for  Libya ,  At Tāj
# Retrieve geolocation for  Libya ,  Al Abyār
# Retrieve articles for  Libya ,  Al Abyār
# Retrieve geolocation for  Libya ,  Al Marj
# Retrieve articles for  Libya ,  Al Marj
# Retrieve geolocation for  Libya ,  Tūkrah
# Retrieve articles for  Libya ,  Tūkrah
# Retrieve geolocation for  Libya ,  Bani Walid
# Retrieve articles for  Libya ,  Bani Walid
# Retrieve geolocation for  Libya ,  Mişrātah
# Retrieve articles for  Libya ,  Mişrātah
# Retrieve geolocation for  Libya ,  Al Khums
# Retrieve articles for  Libya ,  Al Khums
# Retrieve geolocation for  Libya ,  Masallātah
# Retrieve articles for  Libya ,  Masallātah
# Retrieve geolocation for  Libya ,  Tarhuna
# Retrieve articles for  Libya ,  Tarhuna
# Retrieve geolocation for  Libya ,  Al Qaţrūn
# Retrieve articles for  Libya ,  Al Qaţrūn
# Retrieve geolocation for  Libya ,  Murzuq
# Retrieve articles for  Libya ,  Murzuq
# Retrieve geolocation for  Libya ,  Ghadāmis
# Retrieve articles for  Libya ,  Ghadāmis
# Retrieve geolocation for  Libya ,  Nālūt
# Retrieve articles for  Libya ,  Nālūt
# Retrieve geolocation for  Libya ,  Al Ajaylat
# Retrieve articles for  Libya ,  Al Ajaylat
# Retrieve geolocation for  Libya ,  Zalţan
# Retrieve articles for  Libya ,  Zalţan
# Retrieve geolocation for  Libya ,  Zuwārah
# Retrieve articles for  Libya ,  Zuwārah
# Retrieve geolocation for  Libya ,  Al Jadīd
# Retrieve articles for  Libya ,  Al Jadīd
# Retrieve geolocation for  Libya ,  Sabhā
# Retrieve articles for  Libya ,  Sabhā
# Retrieve geolocation for  Libya ,  Qasr Abu Hadi
# Retrieve articles for  Libya ,  Qasr Abu Hadi
# Retrieve geolocation for  Libya ,  Sirte
# Retrieve articles for  Libya ,  Sirte
# Retrieve geolocation for  Libya ,  Tagiura
# Retrieve articles for  Libya ,  Tagiura
# Retrieve geolocation for  Libya ,  Ubari
# Retrieve articles for  Libya ,  Ubari
# Retrieve geolocation for  Libya ,  Brak
# Retrieve articles for  Libya ,  Brak
# Retrieve geolocation for  Libya ,  Idrī
# Retrieve articles for  Libya ,  Idrī
# Retrieve geolocation for  Libya ,  Az Zāwīyah
# Retrieve articles for  Libya ,  Az Zāwīyah
# Retrieve geolocation for  Libya ,  Şabrātah
# Retrieve articles for  Libya ,  Şabrātah
# Retrieve geolocation for  Libya ,  Şurmān
# Retrieve articles for  Libya ,  Şurmān
# Retrieve geolocation for  Libya ,  Zawiya
# Retrieve articles for  Libya ,  Zawiya
# Retrieve geolocation for  Sudan ,  Kassala
# Retrieve articles for  Sudan ,  Kassala
# Retrieve geolocation for  Sudan ,  Khartoum
# Retrieve articles for  Sudan ,  Khartoum
# Retrieve geolocation for  Sudan ,  Nyala
# Retrieve articles for  Sudan ,  Nyala
# Retrieve geolocation for  Sudan ,  Shendi
# Retrieve articles for  Sudan ,  Shendi
# Retrieve geolocation for  Sudan ,  Thabit
# Retrieve articles for  Sudan ,  Thabit
# Retrieve geolocation for  Sudan ,  Umm Durman
# Retrieve articles for  Sudan ,  Umm Durman
# Retrieve geolocation for  Sudan ,  Al Hasaheisa
# Retrieve articles for  Sudan ,  Al Hasaheisa
# Retrieve geolocation for  Sudan ,  Al Hilāliyya
# Retrieve articles for  Sudan ,  Al Hilāliyya
# Retrieve geolocation for  Sudan ,  Al Kiremit al ‘Arakiyyīn
# Retrieve articles for  Sudan ,  Al Kiremit al ‘Arakiyyīn
# Retrieve geolocation for  Sudan ,  Al Manāqil
# Retrieve articles for  Sudan ,  Al Manāqil
# Retrieve geolocation for  Sudan ,  Al Masallamiyya
# Retrieve articles for  Sudan ,  Al Masallamiyya
# Retrieve geolocation for  Sudan ,  Wad Medani
# Retrieve articles for  Sudan ,  Wad Medani
# Retrieve geolocation for  Sudan ,  Wad Rāwah
# Retrieve articles for  Sudan ,  Wad Rāwah
# Retrieve geolocation for  Sudan ,  Al Ḩawātah
# Retrieve articles for  Sudan ,  Al Ḩawātah
# Retrieve geolocation for  Sudan ,  Al Qadarif
# Retrieve articles for  Sudan ,  Al Qadarif
# Retrieve geolocation for  Sudan ,  Doka
# Retrieve articles for  Sudan ,  Doka
# Retrieve geolocation for  Sudan ,  Ad-Damazin
# Retrieve articles for  Sudan ,  Ad-Damazin
# Retrieve geolocation for  Sudan ,  Ar Ruseris
# Retrieve articles for  Sudan ,  Ar Ruseris
# Retrieve geolocation for  Sudan ,  Kurmuk
# Retrieve articles for  Sudan ,  Kurmuk
# Retrieve geolocation for  Sudan ,  Zalingei
# Retrieve articles for  Sudan ,  Zalingei
# Retrieve geolocation for  Sudan ,  El Daein
# Retrieve articles for  Sudan ,  El Daein
# Retrieve geolocation for  Sudan ,  Aroma
# Retrieve articles for  Sudan ,  Aroma
# Retrieve geolocation for  Sudan ,  Wagar
# Retrieve articles for  Sudan ,  Wagar
# Retrieve geolocation for  Sudan ,  Omdurman
# Retrieve articles for  Sudan ,  Omdurman
# Retrieve geolocation for  Sudan ,  El Fasher
# Retrieve articles for  Sudan ,  El Fasher
# Retrieve geolocation for  Sudan ,  Kutum
# Retrieve articles for  Sudan ,  Kutum
# Retrieve geolocation for  Sudan ,  Umm Kaddadah
# Retrieve articles for  Sudan ,  Umm Kaddadah
# Retrieve geolocation for  Sudan ,  Ar Rahad
# Retrieve articles for  Sudan ,  Ar Rahad
# Retrieve geolocation for  Sudan ,  Bārah
# Retrieve articles for  Sudan ,  Bārah
# Retrieve geolocation for  Sudan ,  El Obeid
# Retrieve articles for  Sudan ,  El Obeid
# Retrieve geolocation for  Sudan ,  Umm Ruwaba
# Retrieve articles for  Sudan ,  Umm Ruwaba
# Retrieve geolocation for  Sudan ,  Ad Dabbah
# Retrieve articles for  Sudan ,  Ad Dabbah
# Retrieve geolocation for  Sudan ,  Argo
# Retrieve articles for  Sudan ,  Argo
# Retrieve geolocation for  Sudan ,  Dongola
# Retrieve articles for  Sudan ,  Dongola
# Retrieve geolocation for  Sudan ,  Karmah an Nuzul
# Retrieve articles for  Sudan ,  Karmah an Nuzul
# Retrieve geolocation for  Sudan ,  Kuraymah
# Retrieve articles for  Sudan ,  Kuraymah
# Retrieve geolocation for  Sudan ,  Merowe
# Retrieve articles for  Sudan ,  Merowe
# Retrieve geolocation for  Sudan ,  Gebeit
# Retrieve articles for  Sudan ,  Gebeit
# Retrieve geolocation for  Sudan ,  Port Sudan
# Retrieve articles for  Sudan ,  Port Sudan
# Retrieve geolocation for  Sudan ,  Sawākin
# Retrieve articles for  Sudan ,  Sawākin
# Retrieve geolocation for  Sudan ,  Tokār
# Retrieve articles for  Sudan ,  Tokār
# Retrieve geolocation for  Sudan ,  Atbara
# Retrieve articles for  Sudan ,  Atbara
# Retrieve geolocation for  Sudan ,  Berber
# Retrieve articles for  Sudan ,  Berber
# Retrieve geolocation for  Sudan ,  Ed Damer
# Retrieve articles for  Sudan ,  Ed Damer
# Retrieve geolocation for  Sudan ,  El Bauga
# Retrieve articles for  Sudan ,  El Bauga
# Retrieve geolocation for  Sudan ,  El Matama
# Retrieve articles for  Sudan ,  El Matama
# Retrieve geolocation for  Sudan ,  Ad Dindar
# Retrieve articles for  Sudan ,  Ad Dindar
# Retrieve geolocation for  Sudan ,  As Sūkī
# Retrieve articles for  Sudan ,  As Sūkī
# Retrieve geolocation for  Sudan ,  Jalqani
# Retrieve articles for  Sudan ,  Jalqani
# Retrieve geolocation for  Sudan ,  Kināna
# Retrieve articles for  Sudan ,  Kināna
# Retrieve geolocation for  Sudan ,  Maiurno
# Retrieve articles for  Sudan ,  Maiurno
# Retrieve geolocation for  Sudan ,  Singa
# Retrieve articles for  Sudan ,  Singa
# Retrieve geolocation for  Sudan ,  Sinnar
# Retrieve articles for  Sudan ,  Sinnar
# Retrieve geolocation for  Sudan ,  Gereida
# Retrieve articles for  Sudan ,  Gereida
# Retrieve geolocation for  Sudan ,  Abu Jibeha
# Retrieve articles for  Sudan ,  Abu Jibeha
# Retrieve geolocation for  Sudan ,  Al Fūlah
# Retrieve articles for  Sudan ,  Al Fūlah
# Retrieve geolocation for  Sudan ,  Dilling
# Retrieve articles for  Sudan ,  Dilling
# Retrieve geolocation for  Sudan ,  Kadugli
# Retrieve articles for  Sudan ,  Kadugli
# Retrieve geolocation for  Sudan ,  Talodi
# Retrieve articles for  Sudan ,  Talodi
# Retrieve geolocation for  Sudan ,  Geneina
# Retrieve articles for  Sudan ,  Geneina
# Retrieve geolocation for  Sudan ,  Abū Zabad
# Retrieve articles for  Sudan ,  Abū Zabad
# Retrieve geolocation for  Sudan ,  Al Lagowa
# Retrieve articles for  Sudan ,  Al Lagowa
# Retrieve geolocation for  Sudan ,  Al Mijlad
# Retrieve articles for  Sudan ,  Al Mijlad
# Retrieve geolocation for  Sudan ,  An Nuhūd
# Retrieve articles for  Sudan ,  An Nuhūd
# Retrieve geolocation for  Sudan ,  Ad Douiem
# Retrieve articles for  Sudan ,  Ad Douiem
# Retrieve geolocation for  Sudan ,  Al Kawa
# Retrieve articles for  Sudan ,  Al Kawa
# Retrieve geolocation for  Sudan ,  Al Qiţena
# Retrieve articles for  Sudan ,  Al Qiţena
# Retrieve geolocation for  Sudan ,  Kosti
# Retrieve articles for  Sudan ,  Kosti
# Retrieve geolocation for  Sudan ,  Marabba
# Retrieve articles for  Sudan ,  Marabba
# Retrieve geolocation for  Sudan ,  Rabak
# Retrieve articles for  Sudan ,  Rabak
# Retrieve geolocation for  Sudan ,  Tandaltī
# Retrieve articles for  Sudan ,  Tandaltī
# Retrieve geolocation for  Sudan ,  Um Jar Al Gharbiyya
# Retrieve articles for  Sudan ,  Um Jar Al Gharbiyya
# Retrieve geolocation for  Sudan ,  Wad az Zāki
# Retrieve articles for  Sudan ,  Wad az Zāki
# Retrieve geolocation for  Mauritania ,  Adrar
# Retrieve articles for  Mauritania ,  Adrar
# Retrieve geolocation for  Mauritania ,  Assaba
# Retrieve articles for  Mauritania ,  Assaba
# Retrieve geolocation for  Mauritania ,  Brakna
# Retrieve articles for  Mauritania ,  Brakna
# Retrieve geolocation for  Mauritania ,  Dakhlet Nouadhibou
# Retrieve articles for  Mauritania ,  Dakhlet Nouadhibou
# Retrieve geolocation for  Mauritania ,  Gorgol
# Retrieve articles for  Mauritania ,  Gorgol
# Retrieve geolocation for  Mauritania ,  Guidimaka
# Retrieve articles for  Mauritania ,  Guidimaka
# Retrieve geolocation for  Mauritania ,  Hodh Ech Chargui
# Retrieve articles for  Mauritania ,  Hodh Ech Chargui
# Retrieve geolocation for  Mauritania ,  Hodh El Gharbi
# Retrieve articles for  Mauritania ,  Hodh El Gharbi
# Retrieve geolocation for  Mauritania ,  Inchiri
# Retrieve articles for  Mauritania ,  Inchiri
# Retrieve geolocation for  Mauritania ,  Nouakchott
# Retrieve articles for  Mauritania ,  Nouakchott
# Retrieve geolocation for  Mauritania ,  Tagant
# Retrieve articles for  Mauritania ,  Tagant
# Retrieve geolocation for  Mauritania ,  Tiris Zemmour
# Retrieve articles for  Mauritania ,  Tiris Zemmour
# Retrieve geolocation for  Mauritania ,  Trarza
# Retrieve articles for  Mauritania ,  Trarza
# Retrieve geolocation for  Mauritania ,  Atar
# Retrieve articles for  Mauritania ,  Atar
# Retrieve geolocation for  Mauritania ,  Chingueṭṭi
# Retrieve articles for  Mauritania ,  Chingueṭṭi
# Retrieve geolocation for  Mauritania ,  Barkéwol
# Retrieve articles for  Mauritania ,  Barkéwol
# Retrieve geolocation for  Mauritania ,  Kiffa
# Retrieve articles for  Mauritania ,  Kiffa
# Retrieve geolocation for  Mauritania ,  ’Elb el Jmel
# Retrieve articles for  Mauritania ,  ’Elb el Jmel
# Retrieve geolocation for  Mauritania ,  Aleg
# Retrieve articles for  Mauritania ,  Aleg
# Retrieve geolocation for  Mauritania ,  Nouadhibou
# Retrieve articles for  Mauritania ,  Nouadhibou
# Retrieve geolocation for  Mauritania ,  Kaédi
# Retrieve articles for  Mauritania ,  Kaédi
# Retrieve geolocation for  Mauritania ,  Sélibaby
# Retrieve articles for  Mauritania ,  Sélibaby
# Retrieve geolocation for  Mauritania ,  Néma
# Retrieve articles for  Mauritania ,  Néma
# Retrieve geolocation for  Mauritania ,  Aioun
# Retrieve articles for  Mauritania ,  Aioun
# Retrieve geolocation for  Mauritania ,  Akjoujt
# Retrieve articles for  Mauritania ,  Akjoujt
# Retrieve geolocation for  Mauritania ,  Zouerate
# Retrieve articles for  Mauritania ,  Zouerate
# Retrieve geolocation for  Mauritania ,  Rosso
# Retrieve articles for  Mauritania ,  Rosso
# Retrieve geolocation for  Mauritania ,  Tékane
# Retrieve articles for  Mauritania ,  Tékane

# %% [markdown]
# ## Dump articles dictionary to file

# %%
with open(country_articles_file_path, 'w') as file:
    json.dump(country_articles_dict, file)

# %% [markdown]
# # Download the corpus articles

# %% [markdown]
# ## Get Wikipedia article content

# %%
def retrieve_wikipedia_article(article_uri):
    if article_uri.startswith('http'):
        article_title = article_uri.rsplit('/', 1)[-1]
        print('Title = ', article_title)
    else:
        article_title = article_uri
    encoded_article_title = urllib.parse.quote(article_title.encode('utf8'))
    request= 'https://en.wikipedia.org/w/api.php?format=json&action=query&titles='+encoded_article_title+'&prop=extracts&exlimit=max&explaintext&exlimit=max'
    response = requests.get(request).json()
    pageid = list(response['query']['pages'])[0]
    content = response['query']['pages'][pageid]['extract']

    return pageid, content

# %% [markdown]
# ## Read the country-articles dictionary file

# %%
with open(country_articles_file_path, 'r') as file:
    country_articles_dict = json.load(file)

# %% [markdown]
# ## Retrieve articles then dump then into files

# %%
extended_country_articles_dict = dict()

for country in country_articles_dict.keys():
    article_dicts = []
    articles = country_articles_dict[country]
    country_directory = os.path.join(corpus_directory, country)
    if not os.path.exists(country_directory):
        os.makedirs(country_directory)
    else:
      continue
    # loop over articles #
    for article in articles:
      article_dict = dict()
      print('Start dumping file for article ', article)
      pageid, content = retrieve_wikipedia_article(article)
      article_file_name = str(pageid)+'.txt'
      article_file_path = os.path.join(country_directory, article_file_name)
      with open(article_file_path, 'w', encoding='utf-8') as file:
          file.write(content)
          file.close()
      article_dict['title'] = article
      article_dict['path'] = os.path.join(country,article_file_name)
      article_dicts.append(article_dict)
    extended_country_articles_dict[country]=article_dicts
# Out:
# Start dumping file for article  Béni Yenni District
# Start dumping file for article  El Amria
# Start dumping file for article  Aït Bouaddou
# Start dumping file for article  Ouled Si Slimane District
# Start dumping file for article  Guelma Province
# Start dumping file for article  Metlili
# Start dumping file for article  Robbah
# Start dumping file for article  Dar Hassan Pacha
# Start dumping file for article  Bir Ould Khelifa
# Start dumping file for article  Hammam Bou Hadjar District
# Start dumping file for article  University of Laghouat
# Start dumping file for article  Remchi
# Start dumping file for article  Gharbia, Algeria
# Start dumping file for article  Chlef District
# Start dumping file for article  Aïn Séfra
# Start dumping file for article  Semaoune
# Start dumping file for article  Batna (city)
# Start dumping file for article  Ouled Salah, Boumerdès
# Start dumping file for article  Yahia Beniguecha
# Start dumping file for article  Boudjellil
# Start dumping file for article  Sidi Abdelli
# Start dumping file for article  Raouraoua
# Start dumping file for article  Guelma
# Start dumping file for article  Mekla
# Start dumping file for article  Souamâa
# Start dumping file for article  Beni Mellikeche
# Start dumping file for article  Sobha, Algeria
# Start dumping file for article  Merouana
# Start dumping file for article  Sahel River
# Start dumping file for article  Kheneg
# Start dumping file for article  El Mahmal
# Start dumping file for article  HMS Marigold (K87)
# Start dumping file for article  Aïn Fakroun District
# Start dumping file for article  Sidi M'Hamed Ben Ali District
# Start dumping file for article  Kaous, Algeria
# Start dumping file for article  Aïn Abid
# Start dumping file for article  Azzaba, Algeria
# Start dumping file for article  Zaouia El Abidia
# Start dumping file for article  El Karimia
# Start dumping file for article  Timezrit, Boumerdès
# Start dumping file for article  El Hamma, Khenchela
# Start dumping file for article  Miloud Hadefi Stadium
# Start dumping file for article  Zakaria Medjdoub Stadium
# Start dumping file for article  Berreghlou
# Start dumping file for article  Ouargla District
# Start dumping file for article  Azzaba District
# Start dumping file for article  Aïn Touta
# Start dumping file for article  Tebesbest
# Start dumping file for article  Aghbalou, Algeria
# Start dumping file for article  Belhasnet
# Start dumping file for article  El Hadjar Complex
# Start dumping file for article  Boudouaou-El-Bahri
# Start dumping file for article  Chlef
# Start dumping file for article  Hammam Essalihine
# Start dumping file for article  Ain Arnat Airport
# Start dumping file for article  Ouacifs
# Start dumping file for article  Doukkar
# Start dumping file for article  Safir Mosque
# Start dumping file for article  Douera Sportpark Stadium
# Start dumping file for article  Zemmoura District
# Start dumping file for article  El Biar
# Start dumping file for article  Bouzaréah District
# Start dumping file for article  Taxlent
# Start dumping file for article  Touzaline
# Start dumping file for article  USS Leedstown (AP-73)
# Start dumping file for article  1965 Algerian coup d'état
# Start dumping file for article  Ministry of Justice (Algeria)
# Start dumping file for article  El Achir
# Start dumping file for article  Rouissat
# Start dumping file for article  Bouïra
# Start dumping file for article  Béni Maouche District
# Start dumping file for article  Débidibi
# Start dumping file for article  Tabuda
# Start dumping file for article  Larbaâ Nath Irathen
# Start dumping file for article  El Guedid
# Start dumping file for article  Biskra District
# Start dumping file for article  University of Adrar
# Start dumping file for article  Aïn Zaouia
# Start dumping file for article  Mila (city)
# Start dumping file for article  Akbil
# Start dumping file for article  Oued Koriche
# Start dumping file for article  El Abiodh Sidi Cheikh
# Start dumping file for article  Dellys District
# Start dumping file for article  St. Eugene Cemetery
# Start dumping file for article  Medjber
# Start dumping file for article  Draâ Ben Khedda
# Start dumping file for article  Beni Mester
# Start dumping file for article  Ouled Abbes
# Start dumping file for article  Sig, Algeria
# Start dumping file for article  Merchicha
# Start dumping file for article  Fouka District
# Start dumping file for article  Ouled Moussa
# Start dumping file for article  Isser District
# Start dumping file for article  Chébli
# Start dumping file for article  Turenne rail accident
# Start dumping file for article  Bordj Menaïel District
# Start dumping file for article  Tipaza Province
# Start dumping file for article  Belouizdad, Algiers
# Start dumping file for article  Beni Semiel
# Start dumping file for article  Tafna Beni Saf
# Start dumping file for article  Hassi Khelifa District
# Start dumping file for article  Souihla
# Start dumping file for article  Souidania
# Start dumping file for article  Higher National Veterinary School
# Start dumping file for article  Ghilassa
# Start dumping file for article  Sidi Okba Mosque
# Start dumping file for article  Soumaâ
# Start dumping file for article  Amour Range
# Start dumping file for article  Tazoult District
# Start dumping file for article  Miliana
# Start dumping file for article  Kouinine
# Start dumping file for article  Sidi M'hamed Ben Ali
# Start dumping file for article  Aghlal
# Start dumping file for article  Aïn Bessem
# Start dumping file for article  Souk El-Had
# Start dumping file for article  Chéraga
# Start dumping file for article  Sahla Tahtania
# Start dumping file for article  Amieur
# Start dumping file for article  Ouarizane
# Start dumping file for article  Echorouk Plus
# Start dumping file for article  Ouled Si Slimane
# Start dumping file for article  Chemini District
# Start dumping file for article  Tindouf Province
# Start dumping file for article  El Hadjira
# Start dumping file for article  Oued El Alleug
# Start dumping file for article  Guelaât Bou Sbaâ
# Start dumping file for article  Ouled Mahmoud
# Start dumping file for article  El Hadaik
# Start dumping file for article  Aïn Kechra District (Oum El Bouaghi Province)
# Start dumping file for article  Battle of Algiers (1956–1957)
# Start dumping file for article  El Affroun
# Start dumping file for article  Hassi Khelifa
# Start dumping file for article  El Bayadh
# Start dumping file for article  Talassa
# Start dumping file for article  Trifaoui
# Start dumping file for article  Emir Abdelkader University
# Start dumping file for article  Bousfer Air Base
# Start dumping file for article  Akbou
# Start dumping file for article  Sidi Aïssa
# Start dumping file for article  El Kala District
# Start dumping file for article  Djendel Saadi Mohamed
# Start dumping file for article  Mizrana
# Start dumping file for article  Chender
# Start dumping file for article  Bachdjerrah
# Start dumping file for article  El Kseur
# Start dumping file for article  Tessala El Merdja
# Start dumping file for article  Ifri-Ouzellaguen District
# Start dumping file for article  Mostaganem Province
# Start dumping file for article  Bahia Center
# Start dumping file for article  Sidi Fredj
# Start dumping file for article  Aït Khelili
# Start dumping file for article  Algiers Province
# Start dumping file for article  El Barani Mosque
# Start dumping file for article  Aïn El Arbaa
# Start dumping file for article  Bayadha District
# Start dumping file for article  Dar Aziza
# Start dumping file for article  El Bayadh Airport
# Start dumping file for article  Sebdou
# Start dumping file for article  Oued Djer
# Start dumping file for article  Battle of Bab El Bekkouche
# Start dumping file for article  Chebaita Mokhtar
# Start dumping file for article  Bougaâ District
# Start dumping file for article  Sig District
# Start dumping file for article  Souk El Thenine
# Start dumping file for article  Bordj Bou Arréridj District
# Start dumping file for article  Sougueur
# Start dumping file for article  Royal Hotel (Oran)
# Start dumping file for article  Ghamra
# Start dumping file for article  Ténès
# Start dumping file for article  Beni Maouche
# Start dumping file for article  Bérianne District
# Start dumping file for article  Beni Douala
# Start dumping file for article  Tamerna Djedida
# Start dumping file for article  El Har Ihira
# Start dumping file for article  Berrouaghia District
# Start dumping file for article  Zoubiria
# Start dumping file for article  Ouled Djellal District
# Start dumping file for article  Hassi El Ghella
# Start dumping file for article  Chetouane
# Start dumping file for article  Souakria
# Start dumping file for article  Zawiya Thaalibia (Issers)
# Start dumping file for article  Aïn Fakroun
# Start dumping file for article  Sidi Safi
# Start dumping file for article  Guelaât Bou Sbaâ District
# Start dumping file for article  Boufhaima
# Start dumping file for article  Ifigha
# Start dumping file for article  Sidi Amrane
# Start dumping file for article  Martyrs' Memorial, Algiers
# Start dumping file for article  2012 Baghlia bombing
# Start dumping file for article  Bouhanifia District
# Start dumping file for article  Charef District
# Start dumping file for article  Es Sénia
# Start dumping file for article  Abed Hamdani Stadium
# Start dumping file for article  Belezma Range
# Start dumping file for article  Reggane
# Start dumping file for article  Serdj El Ghoul
# Start dumping file for article  Ali Bitchin Mosque
# Start dumping file for article  Zioui Brothers Stadium
# Start dumping file for article  National Polytechnic School (Algeria)
# Start dumping file for article  Adrar Province
# Start dumping file for article  Madrasa Thaalibia
# Start dumping file for article  Ait Bouada
# Start dumping file for article  Sidi Fredj, Boumerdès
# Start dumping file for article  Boghni District
# Start dumping file for article  Aghrib
# Start dumping file for article  Oued El Abtal
# Start dumping file for article  Cirta
# Start dumping file for article  Villa Montfeld
# Start dumping file for article  Saint Augustin Basilica
# Start dumping file for article  Oued Fodda
# Start dumping file for article  Sidi Aoun
# Start dumping file for article  Mechtat Mehedia
# Start dumping file for article  Harchoun
# Start dumping file for article  Si-Mustapha
# Start dumping file for article  Béni Mered
# Start dumping file for article  Ath Mansour Taourirt
# Start dumping file for article  Grarem Gouga District
# Start dumping file for article  Constantine Cable Car
# Start dumping file for article  Zmila
# Start dumping file for article  El Hamdania
# Start dumping file for article  Didouche Mourad
# Start dumping file for article  Théniet El Had
# Start dumping file for article  Ouled Deide
# Start dumping file for article  El Idrissia District
# Start dumping file for article  Medjana
# Start dumping file for article  Irdjen
# Start dumping file for article  Battle of Hippo Regius
# Start dumping file for article  Ouargla Province
# Start dumping file for article  Oum Sahaouine
# Start dumping file for article  Djamaa el Djazaïr
# Start dumping file for article  Béni Douala District
# Start dumping file for article  Dar Chioukh
# Start dumping file for article  Grarem Gouga
# Start dumping file for article  Boufarik
# Start dumping file for article  Timizart
# Start dumping file for article  University of Jijel
# Start dumping file for article  Guenzet District
# Start dumping file for article  Aflou
# Start dumping file for article  Assi Youcef
# Start dumping file for article  Chelghoum Laïd District
# Start dumping file for article  Battle of Mazagran
# Start dumping file for article  Ahmer El Aïn District
# Start dumping file for article  Saharidj
# Start dumping file for article  Ighram
# Start dumping file for article  Oued Meboudja
# Start dumping file for article  Operation Reservist
# Start dumping file for article  Akbou District
# Start dumping file for article  Guelta Zerka
# Start dumping file for article  Meftah District
# Start dumping file for article  Hassi Ben Okba
# Start dumping file for article  Oggaz
# Start dumping file for article  Bordj Bou Arréridj
# Start dumping file for article  Titouna
# Start dumping file for article  Government Palace (Algiers)
# Start dumping file for article  Ouled Bellemou
# Start dumping file for article  Tamsaout, Boumerdès
# Start dumping file for article  Campaign of Tlemcen (1551)
# Start dumping file for article  Debagha
# Start dumping file for article  Annaba District
# Start dumping file for article  Tala Athmane
# Start dumping file for article  Sidi Aïch
# Start dumping file for article  New Stadium of Tizi Ouzou
# Start dumping file for article  Tala Allam
# Start dumping file for article  H'raoua
# Start dumping file for article  M'Sila Province
# Start dumping file for article  Sétif
# Start dumping file for article  Bouchegouf
# Start dumping file for article  Tébessa
# Start dumping file for article  University Hospital of Oran
# Start dumping file for article  Abou El Hassen
# Start dumping file for article  Djaouna
# Start dumping file for article  Mansoura, Tlemcen
# Start dumping file for article  Ahmed Rachedi, Mila
# Start dumping file for article  El Mechouar Mosque
# Start dumping file for article  Amalou, Algeria
# Start dumping file for article  Aït Oumalou
# Start dumping file for article  Toudja
# Start dumping file for article  Oued Rhiou
# Start dumping file for article  Tagdemt
# Start dumping file for article  Rachgoun
# Start dumping file for article  Illizi
# Start dumping file for article  Tizi Rached
# Start dumping file for article  Chéraga District
# Start dumping file for article  Hilton Alger
# Start dumping file for article  Ksar Chellala
# Start dumping file for article  Altava
# Start dumping file for article  Draa Errich
# Start dumping file for article  Mascara Province
# Start dumping file for article  N'Gaous District
# Start dumping file for article  Sougueur District
# Start dumping file for article  Tipaza Longwave Transmitter
# Start dumping file for article  Belkheir
# Start dumping file for article  Sedrata
# Start dumping file for article  El Matmar
# Start dumping file for article  Mohammedia District
# Start dumping file for article  Mazouna District
# Start dumping file for article  Selmana
# Start dumping file for article  Algiers 1 University
# Start dumping file for article  Bouchagroune
# Start dumping file for article  Moggar
# Start dumping file for article  Aïn Deheb
# Start dumping file for article  In Salah Province
# Start dumping file for article  Larbatache
# Start dumping file for article  Bardo National Museum (Algiers)
# Start dumping file for article  NUR Reactor
# Start dumping file for article  Hippo Regius
# Start dumping file for article  Aïn Oussera District
# Start dumping file for article  Dar El Beïda
# Start dumping file for article  1994 Mascara earthquake
# Start dumping file for article  Hammam Melouane
# Start dumping file for article  Soumâa
# Start dumping file for article  M'Tarfa
# Start dumping file for article  Babor Mountains
# Start dumping file for article  Gueddara
# Start dumping file for article  Hammamet, Tébessa
# Start dumping file for article  Miliana District
# Start dumping file for article  Béni-Aïssi
# Start dumping file for article  Naciria District
# Start dumping file for article  Guerrouaou
# Start dumping file for article  Héliopolis, Algeria
# Start dumping file for article  Tizi Ouzou District
# Start dumping file for article  Battle of Constantine
# Start dumping file for article  Baadj
# Start dumping file for article  University of Ouargla
# Start dumping file for article  2009 Algerian military ambush
# Start dumping file for article  Chelata
# Start dumping file for article  Khenchela District
# Start dumping file for article  Nezla
# Start dumping file for article  Chettia
# Start dumping file for article  Ben Khéllil
# Start dumping file for article  Barbacha District
# Start dumping file for article  Sidi Amar, Tipaza
# Start dumping file for article  Mazer Zaouia
# Start dumping file for article  Meraldene River
# Start dumping file for article  Oued Fodda District
# Start dumping file for article  Faidja
# Start dumping file for article  M'Sila Airport
# Start dumping file for article  Sidi Belahcen Mosque
# Start dumping file for article  Ouled Boumerdès
# Start dumping file for article  Battle of Sig
# Start dumping file for article  Beni Ilmane
# Start dumping file for article  El Fehoul
# Start dumping file for article  Aïn El Ibil District
# Start dumping file for article  Dréan District
# Start dumping file for article  Blida
# Start dumping file for article  Great Mosque of Tlemcen
# Start dumping file for article  Al Qods Shopping Mall
# Start dumping file for article  Cheurfa Tizi Tegyar
# Start dumping file for article  Bir Ghbalou
# Start dumping file for article  Béni Saf District
# Start dumping file for article  Aït Aggouacha
# Start dumping file for article  Iron Gates (Algeria)
# Start dumping file for article  Guertoufa
# Start dumping file for article  Megarine
# Start dumping file for article  Sidi El Haloui Mosque
# Start dumping file for article  Ben Allal, Aïn Defla
# Start dumping file for article  Oldowan
# Start dumping file for article  Adrar, Algeria
# Start dumping file for article  El Eulma
# Start dumping file for article  Hennaya District
# Start dumping file for article  Mamounia
# Start dumping file for article  Draria District
# Start dumping file for article  Béni Saf
# Start dumping file for article  Oued El Abtal District
# Start dumping file for article  Ouled Djellal Province
# Start dumping file for article  Chott, Algeria
# Start dumping file for article  Zawiyet Sidi Boushaki
# Start dumping file for article  Stade du 5 Juillet
# Start dumping file for article  Aïn Ben Beida
# Start dumping file for article  El Barka
# Start dumping file for article  Hadadcha
# Start dumping file for article  M'Kira
# Start dumping file for article  Beni Mezline
# Start dumping file for article  Constantinois
# Start dumping file for article  Oued El Ma
# Start dumping file for article  Ait Ouabane
# Start dumping file for article  Kouba, Algeria
# Start dumping file for article  Baraki, Algiers
# Start dumping file for article  Zenata – Messali El Hadj Airport
# Start dumping file for article  Bouredjouane
# Start dumping file for article  Aïn Babouche District
# Start dumping file for article  Issers
# Start dumping file for article  Ouled Bouhmed
# Start dumping file for article  Attatba
# Start dumping file for article  University of Biskra
# Start dumping file for article  Berrahal District
# Start dumping file for article  Chelghoum Laïd
# Start dumping file for article  Freha
# Start dumping file for article  Ministry of Health, Population and Hospital Reform
# Start dumping file for article  Keddara Dam
# Start dumping file for article  Rahmania
# Start dumping file for article  El Attaf District
# Start dumping file for article  Aïn Kercha
# Start dumping file for article  Maala
# Start dumping file for article  Ensigha
# Start dumping file for article  Timezrit District
# Start dumping file for article  Abdellah Ben Salem Mosque
# Start dumping file for article  Draria
# Start dumping file for article  Grande Poste d'Alger
# Start dumping file for article  Koudiat Acerdoune Dam
# Start dumping file for article  El Attaf
# Start dumping file for article  Ouled Sabor
# Start dumping file for article  Chatouane District
# Start dumping file for article  Telergma Airport
# Start dumping file for article  Djebel Aissa National Park
# Start dumping file for article  Frikat
# Start dumping file for article  Teleghma
# Start dumping file for article  Amizour District
# Start dumping file for article  Oued el Maleh
# Start dumping file for article  Beni Yenni
# Start dumping file for article  Bensekrane
# Start dumping file for article  El Idrissi High School
# Start dumping file for article  2008 Zemmouri bombing
# Start dumping file for article  El Fedjoudj
# Start dumping file for article  Aïn Beida, Ouargla
# Start dumping file for article  Baghlia
# Start dumping file for article  Kendira
# Start dumping file for article  Seddouk
# Start dumping file for article  20 August 1955 Stadium (Algiers)
# Start dumping file for article  El Hamadna
# Start dumping file for article  Mâatkas
# Start dumping file for article  Aoulef
# Start dumping file for article  Métlili District
# Start dumping file for article  Témacine District
# Start dumping file for article  Meraïel
# Start dumping file for article  Chaiba
# Start dumping file for article  Arch of Caracalla (Thebeste)
# Start dumping file for article  2011 Boudouaou rail accident
# Start dumping file for article  Ouled Brahem
# Start dumping file for article  Aïn Tagourait
# Start dumping file for article  Guelma Belkheir Airport
# Start dumping file for article  Ras El Aioun
# Start dumping file for article  Aïn El Melh District
# Start dumping file for article  Sidi Rached Viaduct
# Start dumping file for article  Aïn Larbaâ District
# Start dumping file for article  Tiberkanine
# Start dumping file for article  Abdelkrim Kerroum Stadium
# Start dumping file for article  Hamma Bouziane District
# Start dumping file for article  USCGC Sebago (1930)
# Start dumping file for article  Tirmitine
# Start dumping file for article  Bordj Menaïel
# Start dumping file for article  Emir Abdelkader Mosque
# Start dumping file for article  Algiers station
# Start dumping file for article  Aït Hamadouche
# Start dumping file for article  Bouïra District
# Start dumping file for article  Talmat, Boumerdès
# Start dumping file for article  Timizar, Boumerdès
# Start dumping file for article  Skikda Airport
# Start dumping file for article  El Harmilia
# Start dumping file for article  Baghlia District
# Start dumping file for article  Aïn Beïda District
# Start dumping file for article  Zeribet El Oued
# Start dumping file for article  Ouled Yaïch District
# Start dumping file for article  Tiaret
# Start dumping file for article  Toulmout
# Start dumping file for article  Hocine Rouibah Stadium
# Start dumping file for article  Great Mosque of Constantine
# Start dumping file for article  El Bey Mosque
# Start dumping file for article  El Braya
# Start dumping file for article  Medjana District
# Start dumping file for article  Aït Si Saïd
# Start dumping file for article  Dély Ibrahim
# Start dumping file for article  Makouda
# Start dumping file for article  Ben Aknoun
# Start dumping file for article  2007 Batna bombing
# Start dumping file for article  Igilgili
# Start dumping file for article  Oggaz District
# Start dumping file for article  Mahsas
# Start dumping file for article  Boumahra Ahmed
# Start dumping file for article  Hassan Pasha Mosque
# Start dumping file for article  Thellath
# Start dumping file for article  Sétif Province
# Start dumping file for article  Brézina District
# Start dumping file for article  Sefiane
# Start dumping file for article  Salah Bey Mosque
# Start dumping file for article  Ténès District
# Start dumping file for article  University of Guelma
# Start dumping file for article  Timimoun Airport
# Start dumping file for article  Frenda District
# Start dumping file for article  El Hadjar District
# Start dumping file for article  Ouled Farès District
# Start dumping file for article  Aïn Boucif
# Start dumping file for article  Higher National Agronomic School
# Start dumping file for article  Ouled Driss District
# Start dumping file for article  Reguiba
# Start dumping file for article  Les Eucalyptus
# Start dumping file for article  1954 Chlef earthquake
# Start dumping file for article  Bordj Bou Naâma District
# Start dumping file for article  Ben M'Hidi District
# Start dumping file for article  Aïn Oussera Airport
# Start dumping file for article  Zawiya Thaalibia (Algiers)
# Start dumping file for article  Touggourt Province
# Start dumping file for article  Mezala
# Start dumping file for article  Salah Bey District
# Start dumping file for article  1 November 1954 Stadium (Tizi Ouzou)
# Start dumping file for article  Aïn El Hammam
# Start dumping file for article  Kadiria
# Start dumping file for article  Debila
# Start dumping file for article  Ouled Bessa
# Start dumping file for article  Agouni Gueghrane
# Start dumping file for article  Ouled Hocine
# Start dumping file for article  Birtouta
# Start dumping file for article  El Bor
# Start dumping file for article  Lambaesis
# Start dumping file for article  Yattafène
# Start dumping file for article  2014 Algerian Air Force C-130 crash
# Start dumping file for article  Barika
# Start dumping file for article  Omar Hamadi Stadium
# Start dumping file for article  Boutlélis District
# Start dumping file for article  Achir
# Start dumping file for article  Kheïr Eddine District
# Start dumping file for article  Bordj El Kiffan
# Start dumping file for article  Djenah, Boumerdès
# Start dumping file for article  Djeballah Khemissi
# Start dumping file for article  Aït Dahmane
# Start dumping file for article  Tissemsilt Province
# Start dumping file for article  Tigrine, Boumerdès
# Start dumping file for article  Tiaret Province
# Start dumping file for article  Meftah (town)
# Start dumping file for article  Belimour
# Start dumping file for article  Messaâd District
# Start dumping file for article  Notre-Dame d'Afrique
# Start dumping file for article  Z'Goum
# Start dumping file for article  Boudjima
# Start dumping file for article  Le Soir d'Algérie bombing
# Start dumping file for article  Saïda, Algeria
# Start dumping file for article  Bougaa
# Start dumping file for article  Hammedi
# Start dumping file for article  Khemis Miliana
# Start dumping file for article  Souk-Oufella
# Start dumping file for article  El Abiodh Sidi Cheikh District
# Start dumping file for article  Sidi Amar District
# Start dumping file for article  Aïn El Turk District
# Start dumping file for article  El Taref Province
# Start dumping file for article  Alger (department)
# Start dumping file for article  2007 Souk El Had bombing
# Start dumping file for article  Villa Susini
# Start dumping file for article  Hotel El-Djazair
# Start dumping file for article  Tazmalt
# Start dumping file for article  Djelida District
# Start dumping file for article  Casbah of Algiers
# Start dumping file for article  Bouchelaghem
# Start dumping file for article  Botanical Garden Hamma
# Start dumping file for article  Constantine, Algeria
# Start dumping file for article  Youks-les-Bains
# Start dumping file for article  Rock art of the Djelfa region
# Start dumping file for article  Ain El Fouara Fountain
# Start dumping file for article  Habib Bouakeul Stadium
# Start dumping file for article  Naâma Province
# Start dumping file for article  Bourouba
# Start dumping file for article  El Alia Cemetery
# Start dumping file for article  Island of Limacos
# Start dumping file for article  Sidi Khaled District
# Start dumping file for article  Ouled Chebel
# Start dumping file for article  El Ogla, El Oued
# Start dumping file for article  Ksour Range
# Start dumping file for article  Tissemsilt District
# Start dumping file for article  Meurad
# Start dumping file for article  Mecisna
# Start dumping file for article  El Khabouzia
# Start dumping file for article  Centre Nationale des Archives (Algeria)
# Start dumping file for article  El Taref
# Start dumping file for article  2012 Thénia bombing
# Start dumping file for article  Ouled Yaïch, Blida
# Start dumping file for article  Sidi Nâamane
# Start dumping file for article  Port of Wahran
# Start dumping file for article  Rouïba District
# Start dumping file for article  Siege of Oran (1693)
# Start dumping file for article  L'Mekrareg Airport
# Start dumping file for article  Aïn El Hadjel
# Start dumping file for article  Ali Bouyahiaoui
# Start dumping file for article  Tamalous
# Start dumping file for article  Sayada, Algeria
# Start dumping file for article  Djidioua
# Start dumping file for article  Chetma
# Start dumping file for article  EPH Sisters Bedj
# Start dumping file for article  Houari Boumediene Airport
# Start dumping file for article  El H'Madna District
# Start dumping file for article  Aïn Bessem District
# Start dumping file for article  Aïn Abid District
# Start dumping file for article  Chréa
# Start dumping file for article  Robbah District
# Start dumping file for article  Beni Khelifa
# Start dumping file for article  Yakouren
# Start dumping file for article  Tizi
# Start dumping file for article  Zaatra
# Start dumping file for article  Chlef Province
# Start dumping file for article  Public Establishment of Television
# Start dumping file for article  Berrouaghia
# Start dumping file for article  Oued Sly
# Start dumping file for article  El Hadjira District
# Start dumping file for article  Birkhadem
# Start dumping file for article  American International School of Algiers
# Start dumping file for article  Théniet El Had District
# Start dumping file for article  Béni Messous
# Start dumping file for article  Khezaras District
# Start dumping file for article  Djamaa
# Start dumping file for article  Mohamed Hamlaoui Stadium
# Start dumping file for article  Meskiana
# Start dumping file for article  El Taref District
# Start dumping file for article  Peñón of Algiers
# Start dumping file for article  Bin El Ouiden
# Start dumping file for article  M'Chedallah
# Start dumping file for article  Ahl El Oued
# Start dumping file for article  Pasteur Institute of Algeria
# Start dumping file for article  Sidi Merouane
# Start dumping file for article  Larbaâ Nath Irathen District
# Start dumping file for article  Sidi Boutouchent
# Start dumping file for article  Campaign of Tlemcen (1557)
# Start dumping file for article  Ras El Oued District
# Start dumping file for article  Lakhdaria District
# Start dumping file for article  Roman Catholic Diocese of Constantine
# Start dumping file for article  Touggourt
# Start dumping file for article  Thénia District
# Start dumping file for article  Aïn El Hammam District
# Start dumping file for article  Aïn Youcef
# Start dumping file for article  1 November 1954 Stadium (Batna)
# Start dumping file for article  Ammi Moussa District
# Start dumping file for article  Babor, Sétif
# Start dumping file for article  Bouderbala
# Start dumping file for article  Biskra Airport
# Start dumping file for article  Tizi N'Tleta
# Start dumping file for article  Boukadir
# Start dumping file for article  El Messaid
# Start dumping file for article  Koléa
# Start dumping file for article  Reguiba District
# Start dumping file for article  Bir El Djir
# Start dumping file for article  Abderrahmene Bensaci Stadium
# Start dumping file for article  Aïn Oulmene
# Start dumping file for article  Mekla District
# Start dumping file for article  Zawiyet Sidi Boumerdassi
# Start dumping file for article  Ben Farès Mosque
# Start dumping file for article  Bordj Zemoura
# Start dumping file for article  Sidi Khouiled
# Start dumping file for article  Hamou Boutlélis Sports Palace
# Start dumping file for article  Ouled Ahmed Timmi
# Start dumping file for article  Embassy of Sweden, Algiers
# Start dumping file for article  Boumerdès District
# Start dumping file for article  Boudouaou District
# Start dumping file for article  Khezara
# Start dumping file for article  Chiffa
# Start dumping file for article  National Centre of Research in Social and Cultural Anthropology
# Start dumping file for article  Bousfer
# Start dumping file for article  4 March 1956 Stadium
# Start dumping file for article  Fekhara
# Start dumping file for article  Lardjem
# Start dumping file for article  Ouled Sellam District
# Start dumping file for article  Sidi Lakhdar Mosque
# Start dumping file for article  Tissemsilt
# Start dumping file for article  Lakhdaria
# Start dumping file for article  Musti (Tunisia)
# Start dumping file for article  Rusubbicari
# Start dumping file for article  Bir Ghbalou District
# Start dumping file for article  Meggarine Guedima
# Start dumping file for article  Sidi-Ayad
# Start dumping file for article  Oued Smar
# Start dumping file for article  2008 Issers bombing
# Start dumping file for article  Louz, Boumerdès
# Start dumping file for article  El Ouldja, Relizane
# Start dumping file for article  Ahmed Kaïd Stadium
# Start dumping file for article  Mohamed Boudiaf International Airport
# Start dumping file for article  Chellala
# Start dumping file for article  Constantine campaign (1699–1700)
# Start dumping file for article  El-Flaye
# Start dumping file for article  Douéra
# Start dumping file for article  Imsouhal
# Start dumping file for article  Fouka, Algeria
# Start dumping file for article  2006 Boudouaou bombing
# Start dumping file for article  2006 Tidjelabine bombing
# Start dumping file for article  Zaouïa Formation
# Start dumping file for article  N'Gaous
# Start dumping file for article  Jijel
# Start dumping file for article  Ras Ain Amirouche
# Start dumping file for article  Seybouse River
# Start dumping file for article  Aïn Kebira
# Start dumping file for article  Jijel Province
# Start dumping file for article  Djebel Onk mine
# Start dumping file for article  Beni Djellil
# Start dumping file for article  Aït Ali
# Start dumping file for article  Drimini
# Start dumping file for article  Bir el Ater
# Start dumping file for article  Ben Choud
# Start dumping file for article  Bordj Ghedir District
# Start dumping file for article  Tamentfoust
# Start dumping file for article  Ferme Gauthier
# Start dumping file for article  Guidjel
# Start dumping file for article  Hini
# Start dumping file for article  Bou Hanifia
# Start dumping file for article  Tazmalt District
# Start dumping file for article  Zéralda
# Start dumping file for article  Boumagueur
# Start dumping file for article  Debila District
# Start dumping file for article  Ouled Aissa, Boumerdès
# Start dumping file for article  Aït Mahmoud
# Start dumping file for article  Oued Endja
# Start dumping file for article  Abi Youcef
# Start dumping file for article  Charef
# Start dumping file for article  Ain Beida Airport
# Start dumping file for article  Ouled Selama
# Start dumping file for article  Batna District
# Start dumping file for article  Aïn Romana
# Start dumping file for article  Ouled Bendou
# Start dumping file for article  Es Sénia District
# Start dumping file for article  Souk Ahras
# Start dumping file for article  Aïn Arnat District
# Start dumping file for article  Relizane Province
# Start dumping file for article  Ksar Chellala District
# Start dumping file for article  El-Djazair
# Start dumping file for article  Timimoun Province
# Start dumping file for article  Center of Research in Astronomy, Astrophysics, and Geophysics
# Start dumping file for article  Reghaïa
# Start dumping file for article  Hammam Debagh District
# Start dumping file for article  Mostaganem
# Start dumping file for article  Bougara
# Start dumping file for article  Lardjem District
# Start dumping file for article  El Kerma
# Start dumping file for article  Tizi Rached District
# Start dumping file for article  Sebaou River
# Start dumping file for article  El Keurt
# Start dumping file for article  University of Tizi Ouzou
# Start dumping file for article  Ksar El Boukhari District
# Start dumping file for article  Oued Keberit
# Start dumping file for article  Béni Tamou
# Start dumping file for article  Yahia Boushaki
# Start dumping file for article  El Abadia
# Start dumping file for article  Messaâd
# Start dumping file for article  Merdja Sidi Abed
# Start dumping file for article  Sidi M'Hamed
# Start dumping file for article  Bir El Djir District
# Start dumping file for article  El Abadia District
# Start dumping file for article  Cathédrale du Sacré-Cœur d'Alger
# Start dumping file for article  Hammam Guergour
# Start dumping file for article  Batna (département)
# Start dumping file for article  Constantine 1 University
# Start dumping file for article  Mazouna
# Start dumping file for article  Tebabkha
# Start dumping file for article  Ahmed Zabana National Museum
# Start dumping file for article  Bouinan
# Start dumping file for article  Amar Hamam Stadium
# Start dumping file for article  Khemis El Khechna District
# Start dumping file for article  Ministry of Foreign Affairs (Algeria)
# Start dumping file for article  Babor District
# Start dumping file for article  Ahmed Ben Bella Airport
# Start dumping file for article  Foughala
# Start dumping file for article  Bab Ezzouar Shopping Mall
# Start dumping file for article  Blida District
# Start dumping file for article  Azazga
# Start dumping file for article  Raid on Algiers
# Start dumping file for article  Triangle of Death (Algeria)
# Start dumping file for article  Tamalaht
# Start dumping file for article  Adjadja
# Start dumping file for article  Aïn Témouchent District
# Start dumping file for article  M'Chedellah District
# Start dumping file for article  Bouhamza
# Start dumping file for article  Oran Exposition
# Start dumping file for article  Sidi Chami
# Start dumping file for article  Oran Province
# Start dumping file for article  Sidi Boumedienne
# Start dumping file for article  Constantine Province
# Start dumping file for article  Corniche Jijelienne
# Start dumping file for article  Oran
# Start dumping file for article  Laghouat District
# Start dumping file for article  Tolga District
# Start dumping file for article  Ouled Sidi Brahim
# Start dumping file for article  El-Ourit Waterfalls
# Start dumping file for article  Oued Chaaba
# Start dumping file for article  National Library of Algeria
# Start dumping file for article  Zéralda District
# Start dumping file for article  Djebahia
# Start dumping file for article  Bensekrane District
# Start dumping file for article  Battle of Philippeville
# Start dumping file for article  Beni Messous massacre
# Start dumping file for article  Hydra, Algeria
# Start dumping file for article  Baloul
# Start dumping file for article  Aïn Merane District
# Start dumping file for article  Bordj Ghédir
# Start dumping file for article  Menaceur
# Start dumping file for article  Chréa National Park
# Start dumping file for article  Djasr Kasentina
# Start dumping file for article  Sour El-Ghozlane
# Start dumping file for article  Aït Si Amar
# Start dumping file for article  Aït Yahia Moussa
# Start dumping file for article  Cheria
# Start dumping file for article  Ben Mehdi
# Start dumping file for article  Aïn Boucif District
# Start dumping file for article  El Achour
# Start dumping file for article  Sidi Lakhdar District
# Start dumping file for article  Rahbat
# Start dumping file for article  Mohammedia, Algiers
# Start dumping file for article  Bab Azoun
# Start dumping file for article  Aïn El Turk
# Start dumping file for article  Touggourt District
# Start dumping file for article  Tachehat
# Start dumping file for article  18 February Stadium
# Start dumping file for article  El Aouinet
# Start dumping file for article  1825 Blida earthquake
# Start dumping file for article  Ahmed Bey Palace
# Start dumping file for article  El Aouïnet District
# Start dumping file for article  Colonel Lotfi Stadium
# Start dumping file for article  Tlemcen National Park
# Start dumping file for article  Bir Mourad Raïs
# Start dumping file for article  Aït Salah
# Start dumping file for article  Chabet el Ameur
# Start dumping file for article  Ketchaoua Mosque
# Start dumping file for article  Messaoud Zougar Stadium
# Start dumping file for article  University of Science and Technology Houari Boumediene
# Start dumping file for article  Rabah Bitat Airport
# Start dumping file for article  Amizour
# Start dumping file for article  Chlef International Airport
# Start dumping file for article  El Mouradia
# Start dumping file for article  Bab Ezzouar
# Start dumping file for article  Oum El Bouaghi Province
# Start dumping file for article  Bourkika
# Start dumping file for article  August 2010 Baghlia bombing
# Start dumping file for article  Algerian Space Agency
# Start dumping file for article  Tacheta Zougagha
# Start dumping file for article  Mégarine District
# Start dumping file for article  USM Alger Centre d'entraînement et de formation
# Start dumping file for article  Aïn El Hadjar District
# Start dumping file for article  Boufarik District
# Start dumping file for article  Djamaa el Kebir
# Start dumping file for article  Talamali
# Start dumping file for article  Gueldaman caves
# Start dumping file for article  Harbil
# Start dumping file for article  Mouzaïa District
# Start dumping file for article  Mahrane
# Start dumping file for article  Akfadou
# Start dumping file for article  Sidi Moussa, Algeria
# Start dumping file for article  Hassi Bounif
# Start dumping file for article  Mascara District
# Start dumping file for article  Ouadhia
# Start dumping file for article  Rouïba
# Start dumping file for article  8 May 1945 Stadium
# Start dumping file for article  Cheikh Larbi Tébessa Airport
# Start dumping file for article  Aïn Oussera
# Start dumping file for article  Guenzet
# Start dumping file for article  Salah Bey (town)
# Start dumping file for article  Bordj Ben Azzouz
# Start dumping file for article  Aïn El Assel
# Start dumping file for article  Oum El Bouaghi District
# Start dumping file for article  Echorouk TV
# Start dumping file for article  Aït Yahia
# Start dumping file for article  Skikda Province
# Start dumping file for article  Barika District
# Start dumping file for article  Oued Rhiou District
# Start dumping file for article  Tinabdher
# Start dumping file for article  List of ambassadors of Italy to Algeria
# Start dumping file for article  Relizane Airport
# Start dumping file for article  Ras Acrata
# Start dumping file for article  El Karimia District
# Start dumping file for article  Bouzaréah
# Start dumping file for article  Mila Province
# Start dumping file for article  Sidi Yahia, Boumerdès
# Start dumping file for article  Sidi Khaled
# Start dumping file for article  Biskra
# Start dumping file for article  Guemar Airport
# Start dumping file for article  Benchicao
# Start dumping file for article  Boumerdès
# Start dumping file for article  Akaoudj
# Start dumping file for article  Ouaguenoun
# Start dumping file for article  Sidi M'hamed Bou Qobrine Cemetery
# Start dumping file for article  Chigara
# Start dumping file for article  1 November 1954 Stadium (Algiers)
# Start dumping file for article  Nedroma
# Start dumping file for article  Ouanougha
# Start dumping file for article  El Amria District
# Start dumping file for article  Bounouh
# Start dumping file for article  Aïn Bénian, Algiers
# Start dumping file for article  Frenda
# Start dumping file for article  Taourga
# Start dumping file for article  Terny Beni Hdiel
# Start dumping file for article  Zaarouria
# Start dumping file for article  USMA Stadium
# Start dumping file for article  Sidi Slimane, El Oued
# Start dumping file for article  Tamerna Guedima
# Start dumping file for article  Khraïcia
# Start dumping file for article  Baba Hassen
# Start dumping file for article  Beni Fouda, Boumerdès
# Start dumping file for article  Mostaganem Airport
# Start dumping file for article  Oum Drou
# Start dumping file for article  Zorg, Algeria
# Start dumping file for article  Rasfa
# Start dumping file for article  Boukaraï
# Start dumping file for article  Hamadi Krouma
# Start dumping file for article  Cartennae
# Start dumping file for article  Tijijga
# Start dumping file for article  Bordj Tamentfoust
# Start dumping file for article  Sidi Daoud
# Start dumping file for article  Hassi Messaoud
# Start dumping file for article  Tlemcen Province
# Start dumping file for article  Ben Daoud, Boumerdès
# Start dumping file for article  Aïn El Melh
# Start dumping file for article  Ammi Moussa
# Start dumping file for article  Tiza, Boumerdès
# Start dumping file for article  Nakhla, Algeria
# Start dumping file for article  Aïn Taya
# Start dumping file for article  Theveste
# Start dumping file for article  Tifra
# Start dumping file for article  El Eulma District
# Start dumping file for article  Draâ Ben Khedda District
# Start dumping file for article  Sidi Okba District
# Start dumping file for article  Tizi Ghenif
# Start dumping file for article  Hammamet, Algiers
# Start dumping file for article  Tidjelabine
# Start dumping file for article  Oued El Alleug District
# Start dumping file for article  Rahia
# Start dumping file for article  Hussein Dey (commune)
# Start dumping file for article  Talilt
# Start dumping file for article  Apostolic Nunciature to Algeria
# Start dumping file for article  Dar Ben Abdellah
# Start dumping file for article  Naciria
# Start dumping file for article  El Bouni
# Start dumping file for article  Mouzaïa
# Start dumping file for article  Aïn Laloui
# Start dumping file for article  Besbes District
# Start dumping file for article  Tamacine
# Start dumping file for article  Tipasa
# Start dumping file for article  Ouled Fayet
# Start dumping file for article  Ouargla
# Start dumping file for article  Zenata, Algeria
# Start dumping file for article  Djebabra
# Start dumping file for article  Algiers 3 University
# Start dumping file for article  Hussein Dey District
# Start dumping file for article  El Madania
# Start dumping file for article  Seraïdi
# Start dumping file for article  2008 Thénia bombing
# Start dumping file for article  Skikda
# Start dumping file for article  Pointe Pescarde
# Start dumping file for article  Djaâfra District
# Start dumping file for article  Tigdidine
# Start dumping file for article  Ahmed Zabana Stadium
# Start dumping file for article  Bentalha massacre
# Start dumping file for article  2010 Bordj Menaïel bombing
# Start dumping file for article  Timezrit, Béjaïa
# Start dumping file for article  Chémora
# Start dumping file for article  Battle of Jouami' al-Ulama
# Start dumping file for article  Siga
# Start dumping file for article  Oued El Aneb
# Start dumping file for article  Maâtka District
# Start dumping file for article  El Harrach
# Start dumping file for article  Aït Abdelhadi
# Start dumping file for article  Ismaïl Makhlouf Stadium
# Start dumping file for article  Bou Ismaïl, Boumerdès
# Start dumping file for article  Hobba
# Start dumping file for article  Roman Catholic Archdiocese of Algiers
# Start dumping file for article  Tabrahimt
# Start dumping file for article  In Salah Airport
# Start dumping file for article  Sour El Ghozlane District
# Start dumping file for article  Raïs Hamidou, Algeria
# Start dumping file for article  Museum of Modern Art of Algiers
# Start dumping file for article  Boukhalfa
# Start dumping file for article  Petite Kabylie
# Start dumping file for article  Lahlef
# Start dumping file for article  El Malah
# Start dumping file for article  Hasnaoua
# Start dumping file for article  Tizi Ouzou Province
# Start dumping file for article  Nelson Mandela Stadium
# Start dumping file for article  Bir El Ater District
# Start dumping file for article  Maoklane District
# Start dumping file for article  El Ghrous
# Start dumping file for article  Dellys
# Start dumping file for article  Bou Ismaïl District
# Start dumping file for article  Lake of Fetzara
# Start dumping file for article  Siege of Tlemcen (1299–1307)
# Start dumping file for article  Lycée International Alexandre-Dumas
# Start dumping file for article  Sidi Aïch District
# Start dumping file for article  Tipaza
# Start dumping file for article  Cape Caxine
# Start dumping file for article  Bazer Sakhra
# Start dumping file for article  Ben Djerrah
# Start dumping file for article  Makouda District
# Start dumping file for article  Taourirt, Algeria
# Start dumping file for article  El Arfji
# Start dumping file for article  Echatt
# Start dumping file for article  Saoula
# Start dumping file for article  British Council in Algeria
# Start dumping file for article  M'Sila, Algeria
# Start dumping file for article  Hadjout
# Start dumping file for article  1716 Algiers earthquake
# Start dumping file for article  Oued Seguen
# Start dumping file for article  AES Algiers
# Start dumping file for article  Sidi Yahia, Algeria
# Start dumping file for article  Douaouda
# Start dumping file for article  Ramadane Ben Abdelmalek Stadium
# Start dumping file for article  Berrahal
# Start dumping file for article  Tiberguent
# Start dumping file for article  Alger Centre
# Start dumping file for article  Meraldene
# Start dumping file for article  Tamalous District
# Start dumping file for article  Beni Amrane
# Start dumping file for article  El Mokrani
# Start dumping file for article  Narbonne Flour Mill
# Start dumping file for article  Es-Salam nuclear reactor
# Start dumping file for article  Algiers Opera House
# Start dumping file for article  El Magharia
# Start dumping file for article  Aïn Deheb District
# Start dumping file for article  University of Skikda
# Start dumping file for article  Ottoman Algeria
# Start dumping file for article  El Affroun District
# Start dumping file for article  Ahl El Koudia
# Start dumping file for article  Iferhounène District
# Start dumping file for article  Taghzout, El Oued
# Start dumping file for article  Skhirat, Boumerdès
# Start dumping file for article  Gueraïchene
# Start dumping file for article  Aïn Tallout
# Start dumping file for article  El Marsa, Algiers
# Start dumping file for article  Commandant Ferradj Airport
# ...
# Start dumping file for article  Dar Essid Museum
# Start dumping file for article  Sidi Bou Said
# Start dumping file for article  Bouhjar
# Start dumping file for article  Chebika, Tozeur
# Start dumping file for article  Agbia
# Start dumping file for article  Hamet Jerid
# Start dumping file for article  University of Gafsa
# Start dumping file for article  Nefza
# Start dumping file for article  Souk El Kouafi
# Start dumping file for article  Den Den
# Start dumping file for article  Tunis El Manar University
# Start dumping file for article  El Mourouj
# Start dumping file for article  Avenue Mohammed V (Tunis)
# Start dumping file for article  Souk El Azzafine
# Start dumping file for article  A3 motorway (Tunisia)
# Start dumping file for article  National Engineering School of Tunis
# Start dumping file for article  Djemna
# Start dumping file for article  Tronja Mosque
# Start dumping file for article  El Ain, Tunisia
# Start dumping file for article  Stade Bou Kornine
# Start dumping file for article  Chokri Belaid
# Start dumping file for article  Sebkhet Cherita
# Start dumping file for article  École nationale supérieure d'ingénieurs de Tunis
# Start dumping file for article  Tataouine Governorate
# Start dumping file for article  Synagogue Keren Yéchoua
# Start dumping file for article  Monastir Preparatory Engineering Institute
# Start dumping file for article  Jendouba Governorate
# Start dumping file for article  Gare Mahdia
# Start dumping file for article  Charbati Mosque
# Start dumping file for article  Battle of Carthage (698)
# Start dumping file for article  Souk El Dziria
# Start dumping file for article  Regueb
# Start dumping file for article  Evolution of Textile Monument (Ksar Hellal)
# Start dumping file for article  Tunisian Internet Agency
# Start dumping file for article  Ariana Governorate
# Start dumping file for article  Sousse Archaeological Museum
# Start dumping file for article  Ksibet Thrayet
# Start dumping file for article  Zaghouan Governorate
# Start dumping file for article  Tebourba
# Start dumping file for article  Great Mosque of Mahdiya
# Start dumping file for article  Medina of Tunis
# Start dumping file for article  Chotrana
# Start dumping file for article  Manouba Governorate
# Start dumping file for article  Stade du 7 Novembre de Gafsa
# Start dumping file for article  Madrasa El Maghribia
# Start dumping file for article  HMS Manchester (15)
# Start dumping file for article  List of ambassadors of China to Tunisia
# Start dumping file for article  Dar Othman
# Start dumping file for article  El Hafsia Mosque
# Start dumping file for article  Soliman Airstrip
# Start dumping file for article  Tunis Institute of Fine Arts
# Start dumping file for article  Stade Olympique Hammadi Agrebi
# Start dumping file for article  Battle of Djerba
# Start dumping file for article  Mahdia shipwreck
# Start dumping file for article  HMS Havock (H43)
# Start dumping file for article  El Jedid Mosque
# Start dumping file for article  Battle of Ruspina
# Start dumping file for article  Sfax Waste To Methane Gas Project
# Start dumping file for article  Chareb Errajel
# Start dumping file for article  Al Haliq Mosque
# Start dumping file for article  Djebel Zaghouan
# Start dumping file for article  Sakiet Sidi Youssef
# Start dumping file for article  Menzel Jemil
# Start dumping file for article  Lamta Archaeological Museum
# Start dumping file for article  Carthage National Museum
# Start dumping file for article  El Hentati Mosque
# Start dumping file for article  Bizerte
# Start dumping file for article  Kairouan
# Start dumping file for article  El-Mansoura, Tunisia
# Start dumping file for article  Chott Meriem
# Start dumping file for article  Souk Sidi Sridek
# Start dumping file for article  Chikly
# Start dumping file for article  Gremda
# Start dumping file for article  El Mehrass Mosque
# Start dumping file for article  Battle of Longstop Hill
# Start dumping file for article  Victoria Church
# Start dumping file for article  Jérissa
# Start dumping file for article  Stade 15 Octobre
# Start dumping file for article  Diocesan Library of Tunis
# Start dumping file for article  Youssef Dey Mosque
# Start dumping file for article  Russian Orthodox Church, Tunis
# Start dumping file for article  Ghar el-Melh
# Start dumping file for article  Souk Es Sabbaghine
# Start dumping file for article  Souk Sidi Boumendil
# Start dumping file for article  Tourbet Aziza Othmana
# Start dumping file for article  Ariana (Tunisian city)
# Start dumping file for article  Menzel Ennour
# Start dumping file for article  Madrasa Slimania
# Start dumping file for article  Radio Sfax
# Start dumping file for article  Stade Taïeb Mhiri
# Start dumping file for article  Kairouan Governorate
# Start dumping file for article  Acropolium of Carthage
# Start dumping file for article  Abbir Maius
# Start dumping file for article  Mansouria, Tunisia
# Start dumping file for article  Amphitheatre of El Jem
# Start dumping file for article  Moknine
# Start dumping file for article  Zarzis
# Start dumping file for article  Stade El Menzah
# Start dumping file for article  Kasserine Governorate
# Start dumping file for article  Tozeur
# Start dumping file for article  Tataouine
# Start dumping file for article  Ben Arous Governorate
# Start dumping file for article  Bab Jedid (Tunis)
# Start dumping file for article  Ben Gardane
# Start dumping file for article  Hadrumetum
# Start dumping file for article  Madrasa El Bachia
# Start dumping file for article  University of Sousse
# Start dumping file for article  Sadiki College
# Start dumping file for article  Jebel Boukornine
# Start dumping file for article  El Manar Preparatory Engineering Institute
# Start dumping file for article  University of Kairouan
# Start dumping file for article  La Soukra
# Start dumping file for article  Bulla Regia
# Start dumping file for article  La Goulette
# Start dumping file for article  Bet Mordechai Synagogue, La Goulette
# Start dumping file for article  British International School of Tunis
# Start dumping file for article  Souk El Attarine
# Start dumping file for article  Aghlabid Basins
# Start dumping file for article  Bab El Jazira
# Start dumping file for article  Sidi Hassine
# Start dumping file for article  El Fahs
# Start dumping file for article  Hammam-Lif
# Start dumping file for article  El Maâgoula
# Start dumping file for article  Enfidha–Hammamet International Airport
# Start dumping file for article  Souk Es Sabbaghine El Saghir
# Start dumping file for article  Medina of Sousse, Tunisia
# Start dumping file for article  Midoun
# Start dumping file for article  Mahdia Governorate
# Start dumping file for article  Radès
# Start dumping file for article  Ben Arous
# Start dumping file for article  Stade Olympique (Beja)
# Start dumping file for article  Madrasa Andaloussiya
# Start dumping file for article  Djedeida
# Start dumping file for article  Carthage High Commercial Studies Institute
# Start dumping file for article  Bulla Regia Museum
# Start dumping file for article  Abdellia Palace
# Start dumping file for article  Institut maghrébin des sciences économiques et technologiques
# Start dumping file for article  Kasserine Dam
# Start dumping file for article  El Borj Mosque
# Start dumping file for article  Djerba
# Start dumping file for article  Menzel Kamel
# Start dumping file for article  Degache
# Start dumping file for article  Hotels Monastir
# Start dumping file for article  Mahdia
# Start dumping file for article  Tunisia Polytechnic School
# Start dumping file for article  Bou Arada
# Start dumping file for article  Villa Baizeau
# Start dumping file for article  Stade Jlidi
# Start dumping file for article  Cisterns of La Malga
# Start dumping file for article  Skifa Kahla
# Start dumping file for article  Avitta Bibba
# Start dumping file for article  University of Monastir
# Start dumping file for article  Crich-El-Oued
# Start dumping file for article  Baths of Antoninus
# Start dumping file for article  Carthage University
# Start dumping file for article  Souk Es Sekajine
# Start dumping file for article  Raqqada
# Start dumping file for article  Souk El Sagha
# Start dumping file for article  Sidi Amor Mosque
# Start dumping file for article  Siege of Carthage (Third Punic War)
# Start dumping file for article  Utica, Tunisia
# Start dumping file for article  Carthage amphitheatre
# Start dumping file for article  Souk El Beransia
# Start dumping file for article  Université Centrale (Tunis)
# Start dumping file for article  Thimida Regia
# Start dumping file for article  ESPRIT (School)
# Start dumping file for article  National Institute of Applied Science and Technology
# Start dumping file for article  Sahel, Tunisia
# Start dumping file for article  Central Bank of Tunisia
# Start dumping file for article  Ouersnia
# Start dumping file for article  Hajjamine Mosque
# Start dumping file for article  Jebiniana
# Start dumping file for article  Carnot high school Tunis
# Start dumping file for article  Faculty of Dental Medicine of Monastir
# Start dumping file for article  French protectorate of Tunisia
# Start dumping file for article  List of ambassadors of Italy to Tunisia
# Start dumping file for article  Tunisian National Military Museum
# Start dumping file for article  Battle of Sidi Bou Zid
# Start dumping file for article  Sbiba
# Start dumping file for article  Hammam El Rmimi Mosque
# Start dumping file for article  Douar Hicher
# Start dumping file for article  Sidi El Hani
# Start dumping file for article  Sounine
# Start dumping file for article  El Djem
# Start dumping file for article  Nebeur
# Start dumping file for article  Great Mosque of Sousse
# Start dumping file for article  Scillium
# Start dumping file for article  Bir-Abdallah
# Start dumping file for article  Khalidia
# Start dumping file for article  Kalâa Seghira
# Start dumping file for article  Houmt El Souk
# Start dumping file for article  Ben Hmida Mosque
# Start dumping file for article  Stade Ahmed Bsiri
# Start dumping file for article  Majaz al Bab
# Start dumping file for article  Sfax
# Start dumping file for article  Oued Ellil
# Start dumping file for article  Battle of Utica
# Start dumping file for article  Ribat of Monastir
# Start dumping file for article  Ksar Hellal
# Start dumping file for article  Sidi Bou Hadid Mosque
# Start dumping file for article  Saida Adjoula Mosque
# Start dumping file for article  Maktar
# Start dumping file for article  Khniss
# Start dumping file for article  Zaouiet Kontoch
# Start dumping file for article  Matmata, Tunisia
# Start dumping file for article  Thapsus
# Start dumping file for article  Gabès Governorate
# Start dumping file for article  Souk El Ghrabliyya
# Start dumping file for article  Zaghouan
# Start dumping file for article  Menzel Bourguiba
# Start dumping file for article  Stade Olympique de Sousse
# Start dumping file for article  Leptis Parva
# Start dumping file for article  National Library of Tunisia
# Start dumping file for article  Henchir-El-Djemel
# Start dumping file for article  Mediterranean School of Business
# Start dumping file for article  Hammam Sousse
# Start dumping file for article  El Golâa
# Start dumping file for article  Haffouz
# Start dumping file for article  Radio Tunisienne
# Start dumping file for article  Battle of Wadi Akarit
# Start dumping file for article  University of Gabès
# Start dumping file for article  Chapelle Saint-Louis de Carthage
# Start dumping file for article  Kasbah of Sfax
# Start dumping file for article  Sened, Tunisia
# Start dumping file for article  Benghazi Cathedral
# Start dumping file for article  Zawiya District
# Start dumping file for article  Red Castle Museum
# Start dumping file for article  Yafran District
# Start dumping file for article  Second Battle of Brega
# Start dumping file for article  Al Zawiya University
# Start dumping file for article  Maydan al Shajara
# Start dumping file for article  Benghazi Zoo
# Start dumping file for article  Zuwarah
# Start dumping file for article  Battle of Derna (1912)
# Start dumping file for article  Murbat Stadium
# Start dumping file for article  Sabha, Libya
# Start dumping file for article  Action of 16 May 1797
# Start dumping file for article  Siege of Tripoli (1551)
# Start dumping file for article  Marj
# Start dumping file for article  Brega
# Start dumping file for article  Battle of Bayda
# Start dumping file for article  Jafara
# Start dumping file for article  Mitiga International Airport
# Start dumping file for article  Zawiyat al-Dahmani
# Start dumping file for article  Jalu
# Start dumping file for article  2019 Tajoura migrant center airstrike
# Start dumping file for article  Ghardabiya Airbase
# Start dumping file for article  Tripolitania
# Start dumping file for article  Tripoli Zoo
# Start dumping file for article  Al Asmarya University for Islamic Sciences
# Start dumping file for article  Brak, Libya
# Start dumping file for article  Al Jufra Airbase
# Start dumping file for article  Shawashina
# Start dumping file for article  Zlitan Municipality
# Start dumping file for article  Battle of Misrata (2011)
# Start dumping file for article  Masliwa
# Start dumping file for article  Hun Airport
# Start dumping file for article  Tarabulus Zoo Park
# Start dumping file for article  First Battle of Brega
# Start dumping file for article  Hizam al Akhdar District
# Start dumping file for article  Sidi Darghut Mosque
# Start dumping file for article  Yafran
# Start dumping file for article  Murzuq District
# Start dumping file for article  Battle of Tripoli (1911)
# Start dumping file for article  Sabha Airport
# Start dumping file for article  Wadi Lebda Dam
# Start dumping file for article  Action of 22 June 1803
# Start dumping file for article  Fashlum
# Start dumping file for article  Ajdabiya
# Start dumping file for article  Al-Jalah Hospital
# Start dumping file for article  Zliten truck bombing
# Start dumping file for article  Jumayl, Libya
# Start dumping file for article  Bayda, Libya
# Start dumping file for article  Fourth Battle of Brega
# Start dumping file for article  Adiri, Libya
# Start dumping file for article  List of ambassadors of China to Libya
# Start dumping file for article  Msallata
# Start dumping file for article  Marj District
# Start dumping file for article  Gharyan
# Start dumping file for article  Martyrs' Square, Tripoli
# Start dumping file for article  Battle of Ajdabiya
# Start dumping file for article  Al Bayda Stadium
# Start dumping file for article  Battle of Bani Walid
# Start dumping file for article  Apostolic Prefecture of Misurata
# Start dumping file for article  That El Emad Towers
# Start dumping file for article  Waddan, Libya
# Start dumping file for article  Arch of Marcus Aurelius
# Start dumping file for article  Derna Stadium
# Start dumping file for article  Misurata Stadium
# Start dumping file for article  Tripoli protests and clashes (February 2011)
# Start dumping file for article  Misrata
# Start dumping file for article  Ubari
# Start dumping file for article  Leptis Magna
# Start dumping file for article  Sabratha wa Sorman District
# Start dumping file for article  People's Hall, Tripoli
# Start dumping file for article  Royal Palace of Tripoli
# Start dumping file for article  23rd July Lake
# Start dumping file for article  Suliman Ad-Dharrath Arena
# Start dumping file for article  Bani Walid Airport
# Start dumping file for article  First Battle of Benghazi
# Start dumping file for article  Battle of Benghazi (1911)
# Start dumping file for article  Zawiya skirmish
# Start dumping file for article  Kufra
# Start dumping file for article  Atiq Mosque (Benghazi)
# Start dumping file for article  Gurgi Mosque
# Start dumping file for article  Al-Khums
# Start dumping file for article  Wardama
# Start dumping file for article  Sheikh Chadae Stadium
# Start dumping file for article  Tripoli Stadium
# Start dumping file for article  Port of Tripoli
# Start dumping file for article  Third Battle of Brega
# Start dumping file for article  Qatrun
# Start dumping file for article  Joudaim
# Start dumping file for article  Benghazi Lighthouse
# Start dumping file for article  Abu Salim prison
# Start dumping file for article  Battle of Gharyan
# Start dumping file for article  Al-Fuwayhat
# Start dumping file for article  Bab al-Azizia
# Start dumping file for article  Bombardment of Tripoli (1828)

# %% [markdown]
# ## Dump the extended articles dictionary to file

# %%
with open(country_articles_file_path, 'w') as file:
    json.dump(extended_country_articles_dict, file)
